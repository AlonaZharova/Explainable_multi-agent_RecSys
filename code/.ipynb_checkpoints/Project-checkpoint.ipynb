# %% [markdown]
# Alona Zharova, Annika Boer, Julia Knoblauch, Kai Ingo Schewina, Jana Vihs

# %% [markdown]
# # Explainable Multi-Agent Recommendation System for Energy-Efficient Smart Home

# %% [markdown]
# ## Table of Contents
# 1. [Introduction](#Introduction)
#
# 2. [Related_Literature](#Related_Literature)
#
#    2.1 [Explainable AI (XAI)](#Explainable_AI)
#
#    2.2 [Recommender Systems in Smart Home](#Recommender_Systems_SH)
#
#    2.3 [Explainability in RS](#Explainability_RS)
#
# 3. [Methodology](#Methodology)
#
#    3.1 [Prediction Algorithms](#Prediction_Algorithms)
#
#    3.2 [In-Model Approaches](#In-Model)
#
#    3.3 [Post-Model Approaches](#Post-Model)
#
# 4. [Experimental Design](#Experimental_Design)
#
#     4.1 [Overview of Multi- Agent System](#Agent_System)
#
#     4.2 [Evaluation](#Eval)
#
# 5. [Results](#Results)
#
#     5.1 [Performance](#Results_Performance)
#
#     5.2 [Explainability](#Results_Explainability)
#
#     5.3 [Final Recommendation](#Final_rec)
#
# 6. [Discussion](#Discussion)
#
# 7. [Conclusion](#Conclusion)
#
# [References](#Refs)
#
# [Appendix](#Appendix)

# %%
# Necessary packages to run notebook:
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import json
plt.rcParams["figure.figsize"] = (16,5)
import shap
shap.initjs()

from IPython.display import Latex
from IPython.display import Image

from helper_functions import Helper
from agents import Evaluation_Agent
from agents import Preparation_Agent
from agents import Activity_Agent, Usage_Agent, Load_Agent, Price_Agent, X_Recommendation_Agent, Explainability_Agent
from copy import deepcopy

import warnings
warnings.filterwarnings("ignore")
import os
from datetime import datetime
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};return e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=410)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,
# ...

# %%
helper = Helper()
helper.save_weather(house_id=3)

# %%
DATA_PATH = '../data/'
EXPORT_PATH = '../export/'

# %%
# preparation of data
truncation_params = {
    'features': 'all',
    'factor': 1.5,
    'verbose': 1
}

scale_params = {
    'features': 'all',
    'kind': 'MinMax',
    'verbose': 1
}

aggregate_params = {
    'resample_param': '60T'
}

shiftable_devices = ['Tumble Dryer', 'Washing Machine', 'Dishwasher'] # computer und tv sind m. E. non-shiftable, VR

device_params = {
    'threshold': 0.15
}

load_pipe_params = {
    'truncate': truncation_params,
    'scale': scale_params,
    'aggregate': aggregate_params,
    'shiftable_devices': shiftable_devices,
    'device': device_params
}

threshold = 0.01
active_appliances = ['Toaster', 'Tumble Dryer', 'Dishwasher', 'Washing Machine','Television', 'Microwave', 'Kettle']

activity_params = {
    'active_appliances': active_appliances,
    'threshold': threshold
}

time_params = {
    'features': ['hour', 'day_name']
}

activity_lag_params = {
    'features': ['activity'],
    'lags': [24, 48, 72]
}

activity_pipe_params = {
    'truncate': truncation_params,
    'scale': scale_params,
    'aggregate': aggregate_params,
    'activity': activity_params,
    'time': time_params,
    'activity_lag': activity_lag_params
}

#load agent
device_params = {
    'threshold': threshold
}

#usage agent
device = {
    'threshold' : threshold}

aggregate_params24_H = {
    'resample_param': '24H'
}

usage_pipe_params = {
    'truncate': truncation_params,
    'scale': scale_params,
    'activity': activity_params,
    'aggregate_hour': aggregate_params,
    'aggregate_day': aggregate_params24_H,
    'time': time_params,
    'activity_lag': activity_lag_params,
    'shiftable_devices' : shiftable_devices,
    'device': device
}

household_id = 3
household = helper.load_household(DATA_PATH, household_id, weather_sel=True)

# calling the preparation pipeline
prep = Preparation_Agent(household)
activity_df = prep.pipeline_activity(household, activity_pipe_params)
load_df, _, _ = prep.pipeline_load(household, load_pipe_params)
usage_df = prep.pipeline_usage(household, usage_pipe_params)

# load price data
price_df = helper.create_day_ahead_prices_df(DATA_PATH, 'Day-ahead Prices_201501010000-201601010000.csv')

activity_df.to_pickle('../data/processed_pickle/activity_df.pkl')
load_df,_, _ .to_pickle('../data/processed_pickle/load_df.pkl')
usage_df.to_pickle('../data/processed_pickle/usage_df.pkl')
price_df.to_pickle('../data/processed_pickle/price_df.pkl')
# Out:
# [outlier truncation: Unix]: 100%|████████████████████████████████████████| 6994594/6994594 [00:11<00:00, 587901.18it/s]
# [outlier truncation: Unix]: 0 outliers were truncated.
# [outlier truncation: Aggregate]: 100%|███████████████████████████████████| 6994544/6994544 [00:11<00:00, 612378.39it/s]
# [outlier truncation: Aggregate]: 828082 outliers were truncated.
# [outlier truncation: Toaster]: 100%|█████████████████████████████████████████| 14697/14697 [00:00<00:00, 459246.10it/s]
# [outlier truncation: Toaster]: 3900 outliers were truncated.
# [outlier truncation: Fridge-Freezer]: 100%|██████████████████████████████| 3720281/3720281 [00:05<00:00, 694767.83it/s]
# [outlier truncation: Fridge-Freezer]: 436403 outliers were truncated.
# [outlier truncation: Freezer]: 100%|█████████████████████████████████████| 2834030/2834030 [00:04<00:00, 587097.12it/s]
# [outlier truncation: Freezer]: 263181 outliers were truncated.
# ...

# %% [markdown]
# ## 1. Introduction  <a name="Introduction" id="Introduction"></a>
# Energy use has seen a steady increase across the world over the last decades and will likely increase further by 1.3% per year for OECD countries (Economidou et al. 2020). A possible solution to tackle the energy efficiency problem that arises from these circumstances is behavioral change to energy usage of consumers (Fraternali et al. 2017). One approach to achieve behavioral change is the usage of recommender systems, that suggest actions to improve energy efficiency (Alsalemi et al. 2019).
#
# To achieve a higher persuasiveness and therefore effectiveness of the recommender systems, recent research has highlighted the importance of explainability of recommendations (Zhang & Chen 2020). Himeur et al. (2021) review existing approaches for recommender systems for energy efficiency and identify a research gap for the explainability problem.
#
# Our approach tries to address this issue by incorporating a multi-agent recommender system, that consists of eight agents, that all address a different task (i.e. data preparation, predicting probabilities for availability, device usage and their load, evaluating and providing recommendations as well as their respective explanations). We apply the approach by Riabchuk et al. (forthcoming) and improve several aspects with regard to its performance by testing multiple other models for the prediction tasks. A more comprehensive overview can be found in Section 3. Furthermore, we focus on explainability of the recommendations to improve persuasiveness by applying three approaches derived from explainable AI (XAI), i.e. local interpretable model-agnostic explanations (LIME), Shapley additive explanations (SHAP) and the explainable boosting machine (EBM).
#
# The structure of our notebook is as follows: first we provide an overview over related literature in the domains of XAI, recommender systems in smart homes and explainability in recommender systems. Section 3 displays our applied methodology, i.e. XAI algorithms as well as the prediction algorithms. Following, we present our experimental design by discussing data organization and our evaluation. Finally, we provide results with regard to performance and explainability, followed by a critical discussion including contribution, limitations and future research.

# %% [markdown]
# ## 2. Related Literature  <a name="Related_Literature" id="Related_Literature"></a>
#
# To provide an overview over related literature in the area of explainability in the energy efficiency for smart home domain, we first describe the taxonomy and assessment criteria of explainable artificial intelligence methods. Following, we present the categorization of recommender systems in smart homes and classify our approach within the space of possibilities. Finally, we discuss the few already published methods in the explainability for recommender systems area.

# %% [markdown]
# ### 2.1 Explainable AI (XAI) <a name="Explainable_AI" id="Explainable_AI"></a>
#
# #### 2.1.1 Taxonomy <a name="Tax"></a>
#
# To navigate the space of explanation methods, we use the taxonomy of Singh et al. (2020) shown in Figure 1. This scheme presents one of many ways to classify different explainability methods. Therefore, four questions are put to the reader mentioned below.
#
# <img src="../pictures/Taxonomy_Singh.png" width=750 align="center"/>

# %% [markdown]
# <center>Figure 1: Taxonomy of XAI approaches (Singh et al., 2020) </center>
# <br>

# %% [markdown]
# #### Model-Specific vs. Model-Agnostic
#
# First, it needs to be determined if the model can explain a particular model (model-specific) or any type of black-box model (model-agnostic). The model-specific approaches are based on the parameters of the individual models whereas model-agnostic methods are usually performed post-hoc and do not depend on the internal model weights or structural parameters.
#
# #### Global Methods vs. Local Methods:
#
# Then, the models are divided into local and global models, depending on their capability to explain a particular instance or the entire model. The explainers of local models hence aim at explaining the reasons for the decision of a black-box model for a specific instance. Since we want to help the user in understanding a single recommendation, we will focus on local approaches.
#
# According to Bodria et al. (2021) there are four in-model explanation methods for tabular data (feature importance, rule based approaches, prototypes and counterfactuals) that we present in the following. The first category groups methods that explain the black-box model using *feature importance*. They hence determine a vector $e = {e_1,e_2,...,e_m}$ that assigns an importance value $e_i \in e$ to the $i^{th}$ feature. The sign and the magnitude of each $e_i$ provides insights into the contribution of the feature to the black-box model's decision $b(x)$ by an $e_i<0$ for a negative contribution of a feature and $e_i>0$ for a positive one. If the value equals zero, it means that the feature does not contribute to the output decision.
#
# The second explanation method for tabular data is a *rule based* one. The decision rule has the form $p \rightarrow y$ using the premise $p$ that comprises a Boolean condition on feature values and the consequence of the rule $y$. Moreover, $p$ combines split conditions of the form $x_i \in [v_i^{(l)}, v_i^{(u)}]$, where the feature $x_i$ is bound by the values $v_i^{(l)}$ and $v_i^{(u)}$ in the area of $x_i$, extended with $\pm\infty$. Hence, if all conditions of $p$ are evaluating to true, an instance $x$ satisfies a rule $r$. This means that the interpretable predictor fairly mimics the behavior of the black-box model. So the rule $p\rightarrow y$ can be used to explain the decision $g(x)=y$.
#
# Another explanation method is the application of *prototypes*. These are objects representing a set of similar records. Those records can be of different types. One possibility is that it is a record from the training dataset in the neighborhood of the data $x$. Then it can be a centroid of a cluster to which $x$ belongs to and alternatively, it can be a synthetic record that generates an ad-hoc process. Moreover, the user is able to understand the model's structure because of records resembling the own ones.
#
# The last here mentioned explanation method uses *counterfactuals*, often mentioned as the opposite of prototypes. Examining dependencies, this procedure focuses on the differences that lead to opposite predictions regarding $b(x)=y$. The counterfactual explanation first lists the values $x_1,x_2,...,x_n$ of $x$ leading to the output $b(x)=y$ and then mentions the outcome $b(\bar{x})=\lnot y$ that would result of changing the values of $x$ to $x_1^1,x_2^1,...,x_n^1$ holding all other variables constant.
#
# In this paper we will use feature importance approaches since we can draw text and plot explanations for the user of the recommendation system by applying them.
#
# #### Pre-Model vs. In-Model vs. Post-Model
# Additionally, the explanation can be extracted pre-model, in-model or post-model. On the one hand, we use in-model explanations derived from prediction algorithms that are already inherently explainable. On the other hand, we present post-model explanations that help interpret what the model learned during the training.
#
# #### Surrogate Methods vs. Visualization Methods
# Last but not least, we distinguish between surrogate and visualization methods. Surrogate methods on the one hand work separately from the model and are trained to approximate the predictions of a black box model whereas the visualization methods output a graph that explains the black-box model itself.

# %% [markdown]
# #### 2.1.2 Criteria <a name="Criteria"></a>
#
# Robnik-Šikonja & Bohanec (2018) compile the following properties that differentiate the explainability models:
# - Expressive Power: What logic does the explanation (e.g. if-then-rules) follow and how is the explanation displayed?
# - Translucency: Does the model decompose the predictive model (decomposition), treat the model as black box (pedagogical), or mix these approaches?
# - Portability: Can the model be used on multiple predictive models i.e. is it model specific or agnostic?
# - Algorithmic complexity: How time-consuming are the computations?
#
# Carvalho et. al (2019) propose additional properties:
# - Stability: How stable are the explanations?
# - Data sampling/permutation: How do the algorithms shuffle the data to derive the feature importance?
#
# Note, that there is no consensus in the literature on which criteria to consult as it is very situation-dependent.
# For our context, we do not regard the portability but only evaluate LIME and SHAP that offer model-agnostic explainers.
# Translucency is not important for that same reason since "model-agnostic methods have zero translucency" (Carvalho et al., 2019).
# All other criteria are used to describe and differentiate the explainability methods in section 3.
#
# Besides the explainability approaches, we also have to compare the final explanations that the models offer. To that end, Doshi-Valez & Kim (2017) classify three options to evaluate the explainability approaches.
#
# Firstly, *Application grounded Evaluation* involves using humans in the real setting, i.e. we need subjects that use our recommender system in their smart home and evaluate the usefulness of the offered explanation.
#
# Secondly, *Human-grounded Metrics* would involve humans but not necessarily include the explainability
# approach in a real task. In our case, we could do experiments in which subjects have to choose between the explainability approach, e.g. based on their preference.
#
# Thirdly, Doshi-Valez & Kim (2017) propose *Functionally-grounded Evaluation* that uses proxies to evaluate the
# explainability approach.
# We use the third approach as evaluations that involve the actual application of the recommender system are out of scope for this research and the evaluation with humans and simplified tasks might not offer much external validity to the real setting. The specific proxies that we use for evaluating the individual explanations are described in Section 4.

# %% [markdown]
# ### 2.2 Recommender Systems in Smart Home <a name="Recommender_Systems_SH" id="Recommender_Systems_SH"></a>
# Himeur et al. (2021) recently reviewed the existing approaches for recommender systems in smart homes and deliver an exhaustive taxonomy, of which we will shortly present two aspects to classify our own system in the space of possibilities.
#
# Regarding the objective of the recommender system, there exist two types, namely strategy recommenders, and action recommenders (Himeur et al. 2021). While the first type deals with long-term questions, such as the prediction of energy consumption in a building, the second tries to recommend actions to the occupants in order to optimize their behavior. Therefore, we apply an action recommender.
#
# Secondly, there exist a multitude of methodologies and algorithms to achieve the task of energy efficiency by providing recommendations to users. The different options are displayed in Table 1.
# <p>
# <center>Table 1: Related Approaches on Recommender Systems in Smart Home </center>
#
# <style type="text/css">
# .tg  {border-collapse:collapse;border-spacing:0;}
# .tg td{border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;
#   overflow:hidden;padding:10px 5px;word-break:normal;}
# .tg th{border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;
#   font-weight:normal;overflow:hidden;padding:10px 5px;word-break:normal;}
# .tg .tg-0lax{text-align:left;vertical-align:top}
# </style>
# <table class="tg">
# <thead>
#   <tr>
#     <th class="tg-0lax"><span style="font-weight:bold">Methodology</span></th>
#     <th class="tg-0lax"><span style="font-weight:bold">Description</span></th>
#   </tr>
# </thead>
# <tbody>
#   <tr>
#     <td class="tg-0lax">Case-based</td>
#     <td class="tg-0lax">Rule-based usage habits recommended to end-users</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax">Collaborative filtering</td>
#     <td class="tg-0lax">Closed set of actions, identify the preferred action</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax">Context-aware</td>
#     <td class="tg-0lax">Recommendations adjusted to circumstances of end-user, historical data as basis</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax">Rasch-based</td>
#     <td class="tg-0lax">Rasch analysis explores probability that end-user follows recommendation</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax">Probabilistic relational models (PRM)</td>
#     <td class="tg-0lax">Captures users and transactions in a relational database and derives tailored recommendations</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax">Fusion-based</td>
#     <td class="tg-0lax">Different kinds of data help producing better predictions of habits, either by aggregating data or using subrecommenders</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax">Deep learning-based</td>
#     <td class="tg-0lax">Utilize the ability of deep learning to detect patterns in the data</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax">Classical optimization</td>
#     <td class="tg-0lax">Calculate optimal energy usage and provide insight to end-users and producers</td>
#   </tr>
# </tbody>
# </table>
#
# Our approach is part of the fusion-based recommender systems due to our inclusion of multiple data sources (i.e. historical user behavior, weather and energy price data). There is no article identified by Himeur et al. (2021) that combines this objective and methodology, and we therefore address a research gap in this area. Jimenez-Bravo et al. (2019) applied a fusion-based approach to the energy efficiency problem in smart homes by combining electricity prices and household data. Their agent structure allows for similar behavior than our recommender system and therefore serves as an inspiration to our setup. Also, both methods try to achieve our goal by suggesting to shift usages to more optimal timings. Contrarily, they address the strategy objective and do not allow for further data inclusion such as weather data.
#
# Furthermore, we exhibit characteristics of the context-aware approach, as we include circumstances such as the availability of the user while calculating our recommendations. Therefore, we exemplarily discuss two related approaches.
#
# Wei et al. (2018) provide users with shift-schedule recommendations based on their current location data. By generating simulated data from their own commercial building they were able to reduce their energy usage by 25%. While they use the same methodology and target, they do not apply an agent-based system and apply their method in the commercial area, contrary to our private household focus.
#
# Shigeyoshi et al. (2013) apply KNOTES (KNOwledge & Transaction based domestic Energy saving support System) to provide users with advices, that fit their interest. They conduct a social experiment to evaluate their recommendations, but find the effectiveness of their proposed algorithm to be below their expectations. This incurs due to the model not being able to accurately predict user preferences and not being accepted. We try to tackle the problems by improving our model to more accurately predict users preferences and explain them to increase persuasiveness.
#
# Overall, there has been plenty work on recommender systems, as well as in smart home applications, but our specific methodology and objective is not covered by many research articles, while also not including explainability. Therefore, we discuss this additional aspect in the follow subchapter.

# %% [markdown]
# ### 2.3 Explainability in RS <a name="Explainability_RS" id="Explainability_RS"></a>
# In addition to their discussed review of the state-of-the-art, Himeur et al. (2021) also provide an overview of current research gaps in the research area of energy efficient smart homes. We address one of the research gaps, i.e the explainability issue in recommender systems.
#
# While Zhang & Chen (2020) provide an exhaustive review of the current literature on explainability in recommender systems, they do not put a focus on our application environment (i.e. smart homes). Their classification scheme includes the form of explanation (e.g. textual, visual, hybrid, etc.) and the explainable recommendation model (e.g. topic modeling, matrix factorization, post-hoc, etc.).
#
# We utilize textual, post-hoc explanations, while simultaneously addressing the research gap identified by Zhang & Chen (2020) with regards to further aspects of explanation beyond persuasiveness (i.e. trustworthiness). Early research on trustworthiness is conducted by Cramer et al. (2008), that apply a system for artwork recommendations. Their results suggest a positive influence of explainability on the acceptance of the suggestions, while displaying the certainty of the system did not yield positive effects.
#
# Sardianos et al. (2020) apply a context-aware recommendation system in a smart home ecosystem, that additionally delivers economical or ecological advantages, as well as explanations on the decision-making process. By conducting an experimental process, they conclude that only displaying the persuasive fact is not sufficient to achieve significant behavioral change. Contrarily, displaying the advantages, as well as the reasoning behind it, leads to a 19% increase in acceptance ratio.
#
# Overall, there is very few work on explainability in recommender systems in the smart home ecosystem. We address current issues in this research area to increase trustworthiness and therefore behavioral change with regard to economical and ecological improvement.

# %% [markdown]
# ## 3. Methodology <a name="Methodology" id="Methodology"></a>
#
# First, we outline the prediction algorithms without intrinsic explainability capabilities.
# Second, we introduce in-model (model-intrinsic) explainability appraoches.
# Afterwards, we discuss the post-model approaches LIME and SHAP as they are model-agnostic and can therefore explain the prediction of any classifier.

# %% [markdown]
# ### 3.1 Prediction Algorithms  <a name="Prediction_Algorithms" id="Prediction_Algorithms"></a>
#
#
# To address the prediction of availability and usage probabilities in our smart home environment, we use the following traditional prediction algorithms:
#
# **K-Nearest-Neighbour (KNN)**: A classification algorithm (Cunningham et. al. 2020), where examples are classified based on the class of their nearest neighbours.
#
# **XGBoost** : A scalable end-to-end tree boosting system, which is used widely by data scientists to achieve state-of-the-art results (Chen et. al. 2016).
#
# **AdaBoost**: A boosting algorithm which was first introduced by Freund and Schapire (1997), where the main idea is to maintain a distribution or a set of weigths over the training set.
#
# **Random Forest**: A combination of tree predictors, where each tree depends on the values of a random vector sampled independently and with the same distribution for all trees in the forest (Breiman, 2001). Random forests only offer global explainability and are therefore not useful in our use case as an explainability approach.

# %% [markdown]
# ### 3.2 In-Model Approaches <a name="model_intrinsic" id="In-Model"></a>
#
#
# The lack of transparency and accountability in high-stakes decision-making using black-box models implies severe consequences.
# This leads researchers to concentrate on model-intrinsic explainability approaches,that are inherently explainable.
# The glass-box models represent machine learning models designed for interpretability (Nori et. al. 2019).
#
# **Logistic Regression (Logit)**: A statistical model which usually refers to regression analyses for modeling the probability of a certain class or event which in a binary problem easily can be extended to model a multinomial class problem. The model is already inherently explainable because of the interpretability of the coefficients as log-odds (Peng et. al. 2002).
# We will evaluate the performance of the prediction model in Section 5.1 and hence decide if we should use this model for the explanation of the recommendation.
#
# **Explainable Boosting Maschine (EBM)**: A glassbox model, which is a generalized additive model (GAM) of the form
# $$g(E[y]) = \beta_{0} + \sum f_{j}(x_{j}),$$ where $g$ denotes the link function which adapts the GAM to different application settings like classification or regression. The feature function $f_j$ is learned using modern machine learning techniques like bagging and gradient boosting and therefore is capable of learning any feature function. Utilizing the round-robin method the feature function $f_j$ is learned measuring its contribution to the model's prediction mitigating the effects of collinearity. The boosting procedure is carefully constrained to train on one feature at a time at a very low learning rate. As a result, the order of the features does not matter. Additionally, the EBM can add the term
# $$\sum{f_i}_{j}(x_i,x_j)$$
# to the equation above, so that pairwise interaction can be automatically detected. This further increases accuracy without sacrificing understandability. The model represents a fast implementation of the GA$^2$M algorithm proposed by Lou et al. (2013).
# It is highly intelligibile and explainable while designed to have accuracy comparable to state-of-the-art machine learning models like random forest and boosted trees. Further, as an additive model, which means that each feature contributes to predictions in a modular way. Hence, it is easy to reason about the contribution of each feature to the prediciton by plotting $f_j$ (Nori et al. 2019). Yang et al. (2021) stress that, despite its predictive power, EBM sometimes outputs shape functions with unexpected jumps that can get exacerbated with outliers or noisy samples. Explaining the jumps poses a difficulty. Additionally, they find the resulting model from EBM to be extremly complex for high-dimensional data leading to losses in explainability.
#
# The EBM offers global explanation plots providing insight about the feature importance of all features in a summary plot, and simultaniously a graph explaining the influence of one single feature $f_j$ on all predictions. Further, it is possible to create the graph of the explanation of a local instance, similar to LIME and SHAP. In the following, we will show the graphs for the Availability Agent that predicts if a person will be available to use a device at a specific point in time.

# %%
import interpret
from interpret.glassbox.ebm.ebm import ExplainableBoostingClassifier 
from interpret import show
from agents import Activity_Agent
activity_df = pd.read_pickle('../data/processed_pickle/activity_df.pkl')
activity = Activity_Agent(activity_df)
X_train, y_train, X_test, y_test = activity.train_test_split(activity_df, '2014-08-21')

# %%
model = activity.fit(X_train, y_train, 'ebm')
show(model.explain_global())
# Out:
# <!-- http://127.0.0.1:7001/2023950132800/ -->
# <iframe src="http://127.0.0.1:7001/2023950132800/" width=100% height=800 frameBorder="0"></iframe>

# %% [markdown]
# The plot above shows the global feature importance created by the EBM. The summary page presents a ranking of the most important features overall whereas the dropdown menu *Select Component to Graph* provides a switch to a visualization of each function $f_j$ presenting a global explanation for the varialbe $j$. The blue line shows how the model uses the feature helping e.g., to debug if the model overfits a feature somewhere.
# Consider the graph of the feature temperature *temp*. There exist significant fluctuations as the variable is greater than 0.8. It is hard to explain why the predicted probabilities for being at home at time $t$ change greatly when the temperature increases from 0.8 to 0.85.
# Hence, because of the possibility of discovering the potential mistakes, the availability of graphs is an advantage compared to LIME and SHAP plots that are not able provide the user with this information.
#
# Additionally, there is the option to visualize an individual prediction shown below.

# %%
ebm_local = model.explain_local(X_test, y_test)
show(ebm_local)
# Out:
# <!-- http://127.0.0.1:7001/2023240907024/ -->
# <iframe src="http://127.0.0.1:7001/2023240907024/" width=100% height=800 frameBorder="0"></iframe>

# %% [markdown]
# Please use the dropdown menu above to switch to the local instance 6! The plot explains the decision of a single instance of the availability agent that predicts if a person is available to use a device at a special day at 6 o'clock. Here, the person is predicted to be available (Predicted = 1). The orange bars represent a positive influence on the prediction and the blue bars a negative one. The bars are ranked according to their magnitude of influence on the prediction. This means that the variable *activity_lag_24*, representing if the person was available during the last day, influences the prediction most. It gets visible that interaction terms are included. For example the interaction term *hour x activity_lag_48* has a negative influence on the prediction. An advantage of glass-box models is that these explanations are exact, resulting in easy detection of flaws in the model's decision making. The values shown here are log-odds scores from the EBM, added and passed through a logistic-link function to get the final prediction like in logistic regression (Nori et. al. 2019).
# Using the dropdown menu *Select Component to Graph* a switch between the different local instances is given. In our case, a disadvantage is the layout of this menu because all local predictions are listed one after the other leading to confusion for the user.

# %% [markdown]
# The drawback of the approach is that the documentation is limited since the algorithm was created only recently. However, since the fast implementation and creation of the graphs is very promising, we will later evaluate the performance of the EBM. If the accuracy provides equal results to those of the prediction algorithms explained by LIME and SHAP it is a promising alternative because there is no extra model needed.

# %% [markdown]
# ### 3.2 Post-Model Approaches <a name="model_agnostic" id="Post-Model"></a>
#
#
# Since the black-box models have contributed to a high level of accuracy, the need for model-agnostic approaches is immense.
# As explained above, we focus on the feature importance approaches LIME and SHAP.
# This means they elaborate on which features are most influential in the black-box model's prediction.
# These models do not have direct access to the internal model weights or structural parameters of the black-box model. Therefore, they create a simple surrogate model to explain a local prediction.
# We have also considered other feature importance based
# approaches such as BETA (Lakkaraju et al., 2017), MAPLE (Plumb et al, 2018) MUSE (Lakkaraju et al, 2019)
# but have decided against the usage since the available code and documentation
# is very sparse.

# %% [markdown]
# #### 3.2.1 LIME
#
# One model-agnostic approach is LIME, developed by Ribeiro et al. (2016). LIME stands for "local, interpretable, model-agnostic explanation" and focuses on explaining the prediction of a single instance of data in an interpretable and faithful manner.
# Explaining here means that it is made transparent to the user which characteristics have most influence in the black-box model's prediction. This is made possible by creating a feature importance vector derived locally from records generated randomly in the neighborhood of the instance that has to be explained.
# The predictions produced by LIME are obtained by the minimization problem
# $$\xi(x) = \underset{g~\in~G}{\operatorname{argmin}} \mathcal{L} (b, g, \pi_x) - \Omega (x) $$
#
# where the input data point $x$ is one single instance of the data.
# The optimization problem gets fed with the black-box model $b$, that LIME tries to explain, and the simple model $g \in G$ where $G$ is a family of interpretable models, like e.g., linear regression.
# The first loss term embodies the fidelity of the simple model approximating the complex model in the neighborhood of $x$.
# In order to learn the local behavior of the complex model, the fidelity function $\mathcal{L}$ is approximated by drawing samples, weighted by $\pi(x)$, that behaves like a proximity measure of the sampled data points to $x$.
# The second loss term $\Omega(x)$ is used to regularize the complexity of the simple model $g$ like we know from LASSO or RIDGE regression for the linear model.
#
# Figure 2 shall help for a better intuition of LIME.

# %% [markdown]
# <img src="../pictures/LIME_Image_Intuition.jpg" align="center"/>

# %% [markdown]
# <center>Figure 2: Toy example to present the intuiton for LIME Ribeiro et al. (2016) </center>
# <br>

# %% [markdown]
# The blue and pink background shows the black-box model’s decision function $b$, that is unknown and nonlinear. Thus, it can not be well approximated by a linear model. The aim is to explain the bold red cross, a single instance's prediction of the black-box model. The LIME Algorithm then samples instances around the red cross by changing the feature values just a little bit. It then gets predictions using the complex model $f$.	The sampled instances then are weighted by the proximity to the bold red cross and the dashed line shows the learned explanation, that is locally faithful (but not globally).
#
# The plot below shows the output of the LIME function.

# %%
import lime
from lime import lime_tabular

# %%
model = activity.fit(X_train, y_train, 'logit')
best_hour = 12

# %%
pred_model = activity.fit_Logit(X_train,y_train)
explainer = lime_tabular.LimeTabularExplainer(training_data = np.array(X_train),
                                              mode = "classification", 
                                              feature_names = X_train.columns,
                                              categorical_features = [0])

exp = explainer.explain_instance(data_row = X_test.iloc[best_hour],
                                predict_fn = model.predict_proba)

exp.show_in_notebook(show_table = True)
# Out:
# <html>
#         <meta http-equiv="content-type" content="text/html; charset=UTF8">
#         <head><script>var lime =
# /******/ (function(modules) { // webpackBootstrap
# /******/ 	// The module cache
# /******/ 	var installedModules = {};
# /******/
# /******/ 	// The require function
# /******/ 	function __webpack_require__(moduleId) {
# /******/
# /******/ 		// Check if module is in cache
# /******/ 		if(installedModules[moduleId])
# /******/ 			return installedModules[moduleId].exports;
# /******/
# /******/ 		// Create a new module (and put it into the cache)
# /******/ 		var module = installedModules[moduleId] = {
# /******/ 			exports: {},
# /******/ 			id: moduleId,
# /******/ 			loaded: false
# /******/ 		};
# /******/
# /******/ 		// Execute the module function
# /******/ 		modules[moduleId].call(module.exports, module, module.exports, __webpack_require__);
# /******/
# /******/ 		// Flag the module as loaded
# /******/ 		module.loaded = true;
# /******/
# ...

# %% [markdown]
# It is a list of local explanations, reflecting the contribution of the features to the individual prediction of the black-box model. The output shown here is again about the availability agent and resambles the EBM local output. Because of the prediction probability of 0.64 for class 1 being higher than the threshold 0.5, the predicted value is 1, so the person is predicted to be available. The graph in the middle ranks the features according to their impact on the prediction. The orange bars show features pushing the prediction into the positive direction and the blue bars are pushing it in the negative direction. Here, the fact that the person was at home during the last day has most influence on the prediction. The orange bar here signifies that the influence is positive. The features with a value of 0 do not have any influence whereas the fact that the windspeed is higher than 0.64 exerts negative influence on the prediction.

# %% [markdown]
# **Evaluation with Criteria**
#
# We will now use the criteria mentioned in chapter 2 to assess the explainability method LIME. As explained above LIME uses simple linear models to explain the black-box model. Thereby LIME is a pedagogical approach which means that it treats the black box model as something unknown. The method is model agnostic and so it can be used to explain *any* model's prediction including tabular, text and image data. Since the time needed for the calculation of explainations is so essential to the production environment we measure the time needed to create a local explanation in our evaluation.
#
# Alvarez-Melis and Jaakkola (2018) analyzed the stability of LIME's explanations. They found that for complex black-box models the explanations vary considerably for some neighboring inputs and that they are often inconsistent with each other due to their random perturbation and feature selection methods. Hence, for the same prediction differenct explanations can be generated. The lack of stability is an important downside to LIME since users might get confused if the same
# recommendation is explained differently again. However, easier classifier's explanations are fairly stable in their evaluation.
#
# Another problem is caused by possible feature interactions that can stay unnoticed when sampling around the local instance $x$ using a Gaussian distribution. In order to circumvent this, some extensions of LIME were created (Zhou and Chen, 2018). Dieber and Kirrane (2020) conducted an interview to assess LIME's usability. The interview showed that the results produced by the framework are difficult to understand without documentation or an explanation. They advice using the plots with an attached explanation. Another disadvantage considering the LIME procedure is that the width of the kernel needs to be defined by the user. There is no guide helping this and so different kernels need to be applied and assessed concerning the sense of the explanation.

# %% [markdown]
# #### 3.2.2 SHAP (SHapley Additive exPlanations)
#
# SHAP is introduced by Lundberg & Lee (2017) as an approach that builds on the additive methods used by LIME.  They utilize the concept of Shapley Values (SV) from Game Theory to explain the prediction of a black-box model by computing the contribution of each feature to the prediction.
# >"An intuitive way to understand the Shapley value is the following illustration: The feature values enter a room in random order. All feature values in the room participate in the game (= contribute to the prediction). The Shapley value of a feature value is the average change in the prediction that the coalition already in the room receives when the feature value joins them." (Molnar, 2021)
#
# Lundberg & Lee (2017) provide an estimation of SV by adapting some of the variables used in the loss function of LIME. They show that under specific settings the additive model estimates SV which means that the results meet the theoretical properties of local accuracy, missingness and consistency.
#
# In our work, we use two types of explainers provided in the package that both estimate SV.
#
# **KernelExplainer**
# This explainer from the original paper (Lundberg & Lee, 2017) is model agnostic and derives its name from the shapley kernel $ \pi_{x'} $ which no longer reflects the distance as it was the case for LIME.
#
# The algorithm first samples if the features are present in the coalition i.e.
# $z_{k}^{\prime}\in\{0,1\}^{M},\quad k \in\{1,\ldots, K\}$. We then get the prediction for the coalitions with a mapping function $h_x$ which retrieves the original feature values. If the feature is not present in the coalition the feature value is replaced by a random feature from the sample i.e we sample from the marginal distribution. The coalitions are each weighted with the SHAP kernel (Molnar, 2021).
#
# This kernel
# $$
# \pi_{x^{\prime}}\left(z^{\prime}\right)=\frac{(M-1)}{\left(M \text { choose }\left|z^{\prime}\right|\right)\left|z^{\prime}\right|\left(M-\left|z^{\prime}\right|\right)}
# $$
# is predetermined where $M$ represents the number of input features, $|z'|$ is the number of present features in instance $z'$ and $x$ is the local instance we want to explain (Molnar, 2021).
#
#
# The linear model $g\left(z^{\prime}\right)$ hence is represented as
# $g\left(z^{\prime}\right)=\phi_{0}+\sum_{j=1}^{M} \phi_{j} z_{j}^{\prime}$
# where $\phi_{j}$ are the SV we want to estimate. Furthermore, the regularization term $\Omega(g)$ from LIME is dropped which results in the following kernel-weighted squared loss function to be minimized (Lundberg & Lee, 2017):
#
# $$
# L\left(f, g, \pi_{x^{\prime}}\right)=\sum_{z^{\prime} \in Z}\left[f\left(h_{x}\left(z^{\prime}\right)\right)-g\left(z^{\prime}\right)\right]^{2} \pi_{x^{\prime}}\left(z^{\prime}\right).
# $$
#
# The estimated values $\hat{\phi_{j}}$ can be interpreted as SV.

# %% [markdown]
# **TreeExplainer** This tree-specific explaination method is delineated in Lundberg et al. (2020) and recommended for most popular tree-based prediction models as it reduces the computation time drastically to polynomial time.
#
# Note, that the theoretical underpinnings are quite different and we refrain from giving a detailed overview since we only have used it for one of our five models. What differentiates this explainer the most from the agnostic version is that instead of the marginal expectation, TreeSHAP uses conditional expectations to sample absent features (Lundberg et al., 2020).
#
# This becomes a problem if features are correlated as now the estimated SV might not be zero but indicate a contribution where there is none. This is a disadvantage compared to KernelSHAP which potentially creates unintuitive feature attributions if features are correlated (Molnar, 2021).
#
# Moreover, there are different versions available for the TreeExplainer. We use the fastest version of the explainer (*interventional feature perturbation*) which uses a background dataset similar to KernelSHAP. The alternative (*path-dependent perturbation*) estimates SV with the node information about the paths that the features take in the tree (Lundberg et al., 2020).
#
# The visualization for a local prediction is plotted below for the Usage Agent.
# This agent predicts the probability that a specific device is used for that day.

# %%
import shap
shap.initjs()
usage_df = pd.read_pickle('../data/processed_pickle/usage_df.pkl')
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};return e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=410)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,
# ...

# %%
from agents import Usage_Agent
usage = Usage_Agent(usage_df, "Dishwasher")
X_train, y_train, X_test, y_test = usage.train_test_split(usage_df, "2014-11-01", train_start='2013-11-01')
model = usage.fit(X_train, y_train, 'logit')

# %%
#X_train_summary = shap.kmeans(X_train, 10)
X_train_summary = shap.sample(X_train, 100)
explainer = shap.KernelExplainer(model.predict_proba, X_train_summary)
base_value = explainer.expected_value[1]
shap_values = explainer.shap_values(X_test, check_additivity=False)

# %%
display(shap.force_plot(explainer.expected_value[1], shap_values[1], X_test))
# Out:
# <div id='i5GRB5L4UA2AQF7X9BPH6'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
# ...

# %% [markdown]
# The force plot is a concise visual representation of the local explanation introduced by Lundberg et al. in 2018.
# The *base value* corresponds to the mean prediction for the dataset. The red and blue arrows represent the SV: they push the prediction from the base value to a higher (red) or lower (blue) level. The *output value* of 0.7 is the final prediction by SHAP for the instance where the forces have pushed the prediction from the base value (Molnar, 2021).
# Besides the local explanation, SHAP also offers global interpretability visualizations similar to the ones depicted above for EBM.

# %% [markdown]
# **Evaluation with Criteria**
#
# Similarly to LIME, SHAP can explain the prediction for the same data types, offers a model agnostic approach and
# can be characterized as pedagogical.
# As delineated, SHAP builds on the fair distribution of feature importance scores and uses the plots from above to convey their solution to the user.
# However, the interpretation of shapley values is not as easy to the untrained eye.
#
# Moreover, the estimation of SV in general is quite computationnally intensive. SHAP remedies that problem through their estimation at least for the local prediction. Global explainations remain quite slow (Molnar, 2021). As mentioned, we evaluate the computational complexity in the following.
#
#
# One advantage over LIME is that the explanations from SHAP are stable in that sense that re-running with the same inputs will result in the same result. When it comes to the sampling criterion, both LIME and KernelSHAP have the same shortcomings as other permutation-based appraoches as they just use random data points to sample. TreeSHAP partly remedies that problem by sampling from the conditional distribution which however creates other problems i.e. "features that have no influence on the prediction can get a TreeSHAP value different from zero" (Molnar, 2021).
#
# Additionally, from the theoretic properties of the SV, Lundberg & Lee (2017) argue that results from SHAP
# lead to more intuitive results for users in their study.
#
# We use the KernelExplainer for explaining logistic regression (logit), AdaBoost, K-Nearest-Neighbour and Random Forest.
# We summarize the data before with sampling 100 random data instance for a faster estimation.
# For XGboost we will use the TreeExplainer since we expect the estimation to be a lot faster.
#
# After having delineated the different approaches, we present the additions to the multi-agent system and their evaluation in the following section.

# %% [markdown]
# ## 4. Experimental Design  <a name="Experimental_Design" id="Experimental_Design"></a>

# %% [markdown]
# ### 4.1 Overview of Multi- Agent System <a name="Agent_System" id="Agent_System"></a>
# The following picture represents the multi-agent with our modifications. While most agents existed in the approach of Riabchuk et al. (forthcoming), we added substantial functionality to most agents, especially including more comprehensive performance and explainability evaluation. The latter is not included in the overview as it is not part of the final pipeline, but serves as decision support for models within the two domains performance and explainability. Furthermore, we added the Explainability Agent and included weather data. We discuss the previous system as well as our additions shown in Figure 3 in the following.

# %% [markdown]
# <img src="../pictures/structure_new.jpg" width=750 align="center"/>
# <p>
# <center>Figure 3: Adapted Multi-Agent System </center>
# <br>

# %% [markdown]
# #### 4.1.1 Previous Agent System <a name="Previous_Agent_System"></a>
# The previous system includes all agents besides the Explainability Agent, as well as the data sources besides the newly added weather data.
#
# The Price Agent provides electricity price information for the other agents. It uses a pre-defined comma-separated file, but can easily be adapted to dynamically request prices from an API. It outputs a price vector that includes 48 hours of information starting from the day of interest.
#
# The Preparation Agent transforms the original data to a structure that is able to be processed by the following agents. It calculates multiple time-based features from the sensor data, as well as applies basic preprocessing techniques (i.e. scaling and truncation).
#
# While the Availability Agent predicts the presence and availability of a user for each given hour, the Usage Agent calculates probabilities for the usage of each shiftable device on each given day.
#
# The Load Agent extracts the typical loads that occur for each usage of a given device by averaging over historical usages.
#
# Finally, the Recommendation Agent takes the input of the previous three agents and provides a given recommendation. By applying two thresholds for availability and usage probabilities it is able to recommend the best launch hour (i.e. if on day X usage of device Y is likely, we calculate the cheapest hour from the price agent within the likely available hours of the user).

# %% [markdown]
# #### 4.1.2 Explainability Agent <a name="Explainability_agent"></a>
#
# The Explainability Agent is one of our additions to the existing multi-agent system which is
# called within the Recommendation Agent.
#
# To create the recommendation with the accompanying explanation the recommendation
# pipeline is set off for a specific date and a dataframe with
# the (forecasted) prices for the upcoming day.
#
# Besides the predictions by the model for usage and availabiliy, we pull out
# necessary dataframes (X_train, X_test) and the used models.
#
# With these inputs, the Explainability Agent is called and we use the function
# feature_importance() to extract the outputs from the explainability approach. These
# are mainly the feature attributions that the explainability appraoch assigns to the
# features.
#
# The information from the pipeline is saved in a dataframe ('recommendations_table').

# %%
# Load pickle data
activity_df = pd.read_pickle('../data/processed_pickle/activity_df.pkl')
load_df = pd.read_pickle('../data/processed_pickle/load_df.pkl')
usage_df = pd.read_pickle('../data/processed_pickle/usage_df.pkl')
price_df = pd.read_pickle('../data/processed_pickle/price_df.pkl')

# %% [markdown]
# The recommendations are not returned if the activity prediction and the
# usability prediction fall below the thresholds.

# %%
recommend = X_Recommendation_Agent(activity_df, usage_df, load_df, price_df, shiftable_devices, model_type='random forest')
price = recommend.electricity_prices_from_start_time("2014-08-21")
table= recommend.pipeline(date = "2014-08-21", activity_prob_threshold = 0.4,  usage_prob_threshold = 0.7, evaluation=False, weather_sel=False)
table
# Out:
#   recommendation_date           device  best_launch_hour  \
# 0          2014-08-21     Tumble Dryer                12
# 0          2014-08-21  Washing Machine                12
# 0          2014-08-21       Dishwasher                12
#
#    no_recommend_flag_activity  no_recommend_flag_usage  recommendation  \
# 0                           0                        1             NaN
# 0                           0                        1             NaN
# 0                           0                        0            12.0
#
#                          feature_importance_activity  \
# 0                col_name  feature_importance_val...
# 0                col_name  feature_importance_val...
# 0                col_name  feature_importance_val...
#
#                             feature_importance_usage  \
# 0                     col_name  feature_importanc...
# 0                        col_name  feature_import...
# 0                   col_name  feature_importance_...
#
# ...

# %% [markdown]
# After the creation of the table, we derive the appropriate explanation within the
# function "visualize_recommendation" from the recommendation agent.

# %%
recommend.visualize_recommendation(table, price, diagnostics=False)
# Out:
# There is no recommendation for the device Tumble Dryer .
# There is no recommendation for the device Washing Machine .
# You have a recommendation for the following device: Dishwasher
#
# Please use the device on the 21.08.2014 at 12:00 o'clock because it saves you 8.73 % of costs compared to the mean of the day.
#
# We believe you are likely to use the device in the near future since you were active during the last 2 days and have used the device in the last two days.The weather conditions (windspeed:21.39, wind direction:227.2) support that recommendation.
# We based the recommendation on your past activity and usage of the device. We believe you are active today since you were active during the last day.The weather conditions (windspeed:27.7, relative humidity:6.0) support that recommendation.The hour strenghtens that prediction.
# For detailed information switch on the diagnostics parameter.

# %% [markdown]
# The function first outputs the potential savings when using the recommendations.
# This is calculated in the Recommendation Agent by comparing the
# price of the recommended hour with the average daily price.
# This information is meant to incentize the user economically.
#
# Thereafter, the user is informed about what causes the specific recommendation besides the price.
# The explaination for a single device-recommendation is made-up of two parts:
#
# - Usage explanation: Which features lead to the specific usage prediciton for the day?
# - Availability explanation: Which features drive the availability prediction for that hour?
#
#
# We did not include the explanation of the Load Agent since we do not consider the predicted loads as informative to the users.

# %% [markdown]
# #### 4.1.3 Weather Data <a name="Weather"></a>
#
# #### Features
#
# The underlying data consist out of the REFIT Data which are Electrical Load Measurements provided by Murray et al. (2017). The data contains the energy consumption of nine different devices in Watts used in 20 households in the United Kingdom as well as the aggregate energy consumption in each household over the period 2013 to 2015. As the data only contains these energy consumption measured at eight-second intervals, we need to perform a few preparation steps including aggregating the data, cleaning the data, creating our target features and further feature creation. This task is tackled by the Preparation Agent.
# In order to improve our current multi-agent we extend our dataset with specific weather features using the API from meteostat https://github.com/meteostat/meteostat-python.
# The weather might be of crucial importance for the usage of some devices in a household. Hence we scraped the following additional features:
#
# *dwpt* : The dew point in °C
#
# *rhum*: The relative humidity in percent (%)
#
# *temp* : The air temperature in °C
#
# *wdir* : The average wind direction in degrees (°)
#
# *wspd* : The average wind speed in km/h
#
# For some data points there existed missing values, which where imputed by using the k-Nearest-Neighbour algorithm.

# %% [markdown]
# #### Explorative Data Analysis
#
# To investigate our data, especially after the addition of weather data, we perform a short explorative data analysis.

# %%
output, scaled, df = Preparation_Agent(household).pipeline_load(household, load_pipe_params)
# Out:
# [outlier truncation: Unix]: 100%|████████████████████████████████████████| 6994594/6994594 [00:11<00:00, 631640.09it/s]
# [outlier truncation: Unix]: 0 outliers were truncated.
# [outlier truncation: Aggregate]: 100%|███████████████████████████████████| 6994544/6994544 [00:10<00:00, 645633.70it/s]
# [outlier truncation: Aggregate]: 828082 outliers were truncated.
# [outlier truncation: Toaster]: 100%|█████████████████████████████████████████| 14697/14697 [00:00<00:00, 489838.18it/s]
# [outlier truncation: Toaster]: 3900 outliers were truncated.
# [outlier truncation: Fridge-Freezer]: 100%|██████████████████████████████| 3720281/3720281 [00:05<00:00, 653865.12it/s]
# [outlier truncation: Fridge-Freezer]: 436403 outliers were truncated.
# [outlier truncation: Freezer]: 100%|█████████████████████████████████████| 2834030/2834030 [00:04<00:00, 665126.78it/s]
# [outlier truncation: Freezer]: 263181 outliers were truncated.
# ...

# %% [markdown]
# The following correlation plot displays a positive correlation between the usage of the washing machine and the tumble dryer, which was expected, as if you use the washing machine and own a tumble dryer one would usually use it afterwards. Furthermore there seems to be a strong positive correlation between the relative humidity (rhum) and the dew point (dwpt) and a strong negative correlation between the air temperature (temp) and the dew point (dwpt).
# In general, it can be observed that the data are positively correlated with each other, but there are no strong interdependencies.

# %%
plt.title('Correlation of weather features and Usage of Devices')
weather_df = df[['Tumble Dryer_usage', 'Washing Machine_usage', 'Dishwasher_usage','dwpt', 'rhum', 'temp', 'wdir', 'wspd']]
sns.heatmap(weather_df.corr(), annot=True)

# %% [markdown]
# Now we want to examine if a device was used multiple times each day. As for the tumble dryer there exist dates where it was used 8 times, the washing machine was used 9 times a day and the dishwasher was used 7 times a day as a maximum. This is rather rare but interesting for our recommender system when it comes to saving energy and money and must be discussed in terms of further research.

# %%
# Tumble Dryer in use
reIndexed = df.reset_index()
reIndexed['Date'], reIndexed['clock'] = reIndexed['Time'].apply(lambda x: x.date()), reIndexed['Time'].apply(lambda x: x.time())
wm = reIndexed['Washing Machine_usage']==1
td = reIndexed['Tumble Dryer_usage']==1
dw = reIndexed['Dishwasher_usage'] ==1
td_inuse = reIndexed[td]
td_inuse.groupby('Date')[['Tumble Dryer_usage']].count().describe()
# Out:
#        Tumble Dryer_usage
# count          289.000000
# mean             2.480969
# std              1.563633
# min              1.000000
# 25%              1.000000
# 50%              2.000000
# 75%              3.000000
# max              8.000000

# %%
# Washing Machine in use
wm_inuse = reIndexed[wm]
wm_inuse.groupby('Date')[['Washing Machine_usage']].count().describe()
# Out:
#        Washing Machine_usage
# count             330.000000
# mean                2.357576
# std                 1.499550
# min                 1.000000
# 25%                 1.000000
# 50%                 2.000000
# 75%                 3.000000
# max                 9.000000

# %%
# Dishwasher in use
dw_inuse = reIndexed[dw]
dw_inuse.groupby('Date')[['Dishwasher_usage']].count().describe()
# Out:
#        Dishwasher_usage
# count        372.000000
# mean           2.271505
# std            0.916424
# min            1.000000
# 25%            2.000000
# 50%            2.000000
# 75%            2.000000
# max            7.000000

# %% [markdown]
# On average each device is used two times a day. As expected the following distribution plot shows a similiar situation for the usage of the washing machine and the tumble dryer.

# %%
plt.title('Distribution of Tumble Dryer and Washing Machine Usage')
sns.distplot(td_inuse['Date'].value_counts().values)
sns.distplot(wm_inuse['Date'].value_counts().values)
plt.legend(labels=['Tumble Dryer', 'Washing Mashine'])

# %%
plt.title('Distribution of Dishwasher Usage')
sns.distplot(dw_inuse['Date'].value_counts().values, color='green')

# %%
# Look at dates of interest for Tumble dryer and Washing Machine
df_20_04_2014 = df[['dwpt','rhum','temp','wdir','wspd','Tumble Dryer_usage', 'Washing Machine_usage']].filter(like='2014-04-20', axis=0)
df_10_08_2014 = df[['dwpt','rhum','temp','wdir','wspd','Tumble Dryer_usage', 'Washing Machine_usage']].filter(like='2014-08-10', axis=0)
df_03_09_2015 = df[['dwpt','rhum','temp','wdir','wspd','Tumble Dryer_usage', 'Washing Machine_usage']].filter(like='2015-09-03', axis=0)
df_26_06_2014 = df[['dwpt','rhum','temp','wdir','wspd','Tumble Dryer_usage', 'Washing Machine_usage']].filter(like='2014-06-26', axis=0)
df_28_09_2013 = df[['dwpt','rhum','temp','wdir','wspd', 'Tumble Dryer_usage', 'Washing Machine_usage']].filter(like='2013-09-28', axis=0)

# %%
# Look at dates of interest for Dishwasher
df_27_09_2013 = df[['dwpt','rhum','temp','wdir','wspd','Dishwasher_usage']].filter(like='2013-09-27', axis=0)
df_25_11_2014 = df[['dwpt','rhum','temp','wdir','wspd' ,'Dishwasher_usage']].filter(like='2014-11-25', axis=0)
df_19_10_2014 = df[['dwpt','rhum','temp','wdir','wspd', 'Dishwasher_usage']].filter(like='2014-10-19', axis=0)
df_01_07_2014 = df[['dwpt','rhum','temp','wdir','wspd', 'Dishwasher_usage']].filter(like='2014-07-01', axis=0)

# %% [markdown]
# In the following, we will examine the time series of the weather features and the use of the different household devices in order to detect any relations between those properties.
# Especially the dates on which each device is used multiple times are of interest.
# Considering the usage of the washing machine and tumble dryer, the course of the graphs confirms once again that the dryer is mostly used after the washing machine. Almost everytime those devices are used, there seems to be a drop in the weather features, which indicates that those features would be helpful for our recommender system.

# %%
# Draw Plot
def plot_df(df, x, y, title="", xlabel='TIme', ylabel='Value', dpi=100, axvspan=True):
    plt.figure(figsize=(16,5), dpi=dpi)
    plt.plot(x, y, marker='o')
    plt.legend(df_27_09_2013.columns.tolist())

    plt.gca().set(title=title, xlabel=xlabel, ylabel=ylabel)
    plt.show()

plot_df(df_27_09_2013, x=df_27_09_2013.index, y=df_27_09_2013.values, title='Tumble Dryer and Waching Machine Usage on the 27.09.2013')

# %% [markdown]
# ### 4.2 Evaluation <a name="Eval" id="Eval"></a>
#
# To evaluate the performance of our multi-agent model we apply multiple metrics depending on the task. First, we shortly discuss performance measures with regard to the Activity, Usage and Load Agent predictions. Following, we provide a more detailed overview of our explainability measures.

# %% [markdown]
# #### 4.2.1 Performance <a name="Eval_Performance" id="Eval_Performance"></a>
#
# Regarding performance evaluation we investigate two different measures depending on the task. The Usage and Activity Agent perform a classification task and therefore we evaluate their area-under-the-ROC-curve (AUC). The AUC denotes the probability that a random drawn positive observation is correctly ranked higher than a randomly drawn negative observation. This is achieved by applying all possible thresholds to the contingency table and plotting the respective sensitivity (true positive rate) and specificity (true negative rate) of the predictions. We evaluate each day by predicting probabilities of activity and usage and compare them to the true values in our dataframe.
#
# The Load Agent is evaluated by investigating the mean squared error of our predicted load profile to real usages. Since we only average and still apply the methodology of Riabchuk et al. (forthcoming), we do not report the performance measures for the Load Agent.

# %% [markdown]
# #### 4.2.2 Explainability <a name="Eval_Explainability" id="Eval_Explainability"></a>

# %% [markdown]
# When it comes to our evaluation of the explainability approaches we want to quantitatively compare the
# individual explanations that the models offer. The literature does not propose one clear framework which metrics to use as it is also highly application dependent.
# Nevertheless, we will use the following concepts that are widely applied to determine how well
#  the explainability approaches work in giving accurate local explanations (Carvalho et. al, 2019):
#
# **Accuracy** Similar to predictive accuracy, the accuracy of the explanation method refers to how well the explainable model
# predicts unseen instances compared to the real outcome. We will also use the Are Under the ROC-Curve (AUC) as a measure to compare the true labels with the predictions from the explainers.
#
# **Fidelity** This criterion determines how close the prediction from the explainable model is to the black-box model's prediction.
# Therefore, fidelity describes how well the explainability model can imitate the prediction of the black-box model.
# We use the measure AUC again but replace the target label with the predictions from the black-box model.
# Note that Carvalho et. al (2019) mention an interrelation between these two concepts: black-box models with high predictive
# accuracy and explanations that offer a high fidelity are also highly accurate when it comes to real predictions. This is
# the ideal that we would like to achieve.
#
# Additionally, we calculate the *Mean-Absolute-Explainability Error* (MAEE) for every approach to measure not only if
# the decision of the black-box model and the explainability approach is the same but also to measure how close they are to each other.
# This metric represents how well the explainability approaches are calibrated. The formula of the traditionally used
# Mean-Absolute-Error is adapted in the following way to reflect the differences of the prediction from the prediction
# model compared to the explainability model:

# %% [markdown]
# $$ M A E=\frac{1}{N} \sum_{i=1}^{N}\left|y_{pred}-\hat{y_{expl}}\right| $$

# %% [markdown]
# **Efficiency (Algorithmic complexity)** Lastly, we evaluate how efficient the explainability approaches are in calculating
# the local explanations. To the end, we measure the time that each method needs to calculate all the
# local explanations for a day and average the values for all calculations (Carvalho et. al, 2019).
#
# These criteria are evaluated in the Evaluation_Agent with the function 'get_agent_scores' to extract the predictions.
# The list of predictions is then processed as described in chapter 5.2.

# %% [markdown]
# ## 5. Results <a name="Results" id="Results"></a>
#
# Using the methods described above, we conduct measures on the two dimensions of our analysis. First, we present the performance of the Usage and Activity Agent, followed by a thorough examination of our explainability measures.

# %% [markdown]
# ### 5.1 Performance <a name="Results_Performance" id="Results_Performance"></a>
# We apply an exhaustive grid search over the five algorithms listed in Section 3.2 excluding the EBM. The latter is computationally too expensive, as a single run takes more than a day on the LEQR server. Overall, 87 parameter combinations are tested twice, once with and without weather data to quantify the benefit of including additional data and pursuing a fusion-based approach. The detailed results are displayed in the Appendix. Table 2 and 3 list the results for the Activity and Usage Agent for the best parameter combinations, with and without weather data respectively (TD = Tumble Dryer, WM = Washing Machine, DW = Dishwasher, WM_2 = 2nd Washing Machine, WD = Washdryer).
# <p>
# <center> Table 2: Performance Results With Tuned Hyperparameters Including Weather Data </center>
#
# <center>
# <style type="text/css">
# .tg  {border-collapse:collapse;border-spacing:0;}
# .tg td{border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;
#   overflow:hidden;padding:10px 5px;word-break:normal;}
# .tg th{border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;
#   font-weight:normal;overflow:hidden;padding:10px 5px;word-break:normal;}
# .tg .tg-0lax{text-align:left;vertical-align:top}
# </style>
# <table class="tg">
# <thead>
#   <tr>
#     <th class="tg-0lax">With Weather</th>
#     <th class="tg-0lax">Activity</th>
#     <th class="tg-0lax">Usage_TD</th>
#     <th class="tg-0lax">Usage_WM</th>
#     <th class="tg-0lax">Usage_DW</th>
#   </tr>
# </thead>
# <tbody>
#   <tr>
#     <td class="tg-0lax">Logit</td>
#     <td class="tg-0lax">0.836</td>
#     <td class="tg-0lax">0.728</td>
#     <td class="tg-0lax">0.703</td>
#     <td class="tg-0lax">0.684</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax">Random Forest</td>
#     <td class="tg-0lax">0.859</td>
#     <td class="tg-0lax">0.928</td>
#     <td class="tg-0lax">0.932</td>
#     <td class="tg-0lax">0.929</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax">Adaboost</td>
#     <td class="tg-0lax">0.850</td>
#     <td class="tg-0lax">0.779</td>
#     <td class="tg-0lax">0.777</td>
#     <td class="tg-0lax">0.788</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax">KNN</td>
#     <td class="tg-0lax">0.830</td>
#     <td class="tg-0lax">0.760</td>
#     <td class="tg-0lax">0.758</td>
#     <td class="tg-0lax">0.785</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax">XGBoost</td>
#     <td class="tg-0lax">0.852</td>
#     <td class="tg-0lax">0.922</td>
#     <td class="tg-0lax">0.925</td>
#     <td class="tg-0lax">0.922</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax">EBM</td>
#     <td class="tg-0lax">0.854</td>
#     <td class="tg-0lax">0.803</td>
#     <td class="tg-0lax">0.822</td>
#     <td class="tg-0lax">0.842</td>
#   </tr>
# </tbody>
# </table>
# </center>
#
# <br>
# <p>
# <center> Table 3: Performance Results With Tuned Hyperparameters Excluding Weather Data </center>
#
# <style type="text/css">
# .tg  {border-collapse:collapse;border-spacing:0;}
# .tg td{border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;
#   overflow:hidden;padding:10px 5px;word-break:normal;}
# .tg th{border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;
#   font-weight:normal;overflow:hidden;padding:10px 5px;word-break:normal;}
# .tg .tg-0lax{text-align:left;vertical-align:top}
# </style>
# <table class="tg">
# <thead>
#   <tr>
#     <th class="tg-0lax">Without Weather</th>
#     <th class="tg-0lax">Activity</th>
#     <th class="tg-0lax">Usage_TD</th>
#     <th class="tg-0lax">Usage_WM</th>
#     <th class="tg-0lax">Usage_DW</th>
#   </tr>
# </thead>
# <tbody>
#   <tr>
#     <td class="tg-0lax">Logit</td>
#     <td class="tg-0lax">0.838</td>
#     <td class="tg-0lax">0.702</td>
#     <td class="tg-0lax">0.689</td>
#     <td class="tg-0lax">0.676</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax">Random Forest</td>
#     <td class="tg-0lax">0.835</td>
#     <td class="tg-0lax">0.713</td>
#     <td class="tg-0lax">0.683</td>
#     <td class="tg-0lax">0.715</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax">Adaboost</td>
#     <td class="tg-0lax">0.849</td>
#     <td class="tg-0lax">0.710</td>
#     <td class="tg-0lax">0.701</td>
#     <td class="tg-0lax">0.680</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax">KNN</td>
#     <td class="tg-0lax">0.826</td>
#     <td class="tg-0lax">0.738</td>
#     <td class="tg-0lax">0.718</td>
#     <td class="tg-0lax">0.779</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax">XGBoost</td>
#     <td class="tg-0lax">0.845</td>
#     <td class="tg-0lax">0.712</td>
#     <td class="tg-0lax">0.682</td>
#     <td class="tg-0lax">0.710</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax">EBM</td>
#     <td class="tg-0lax">0.846</td>
#     <td class="tg-0lax">0.707</td>
#     <td class="tg-0lax">0.683</td>
#     <td class="tg-0lax">0.700</td>
#   </tr>
# </tbody>
# </table>
#
# <br>
#
# We observe very consistent results for the Activity Agent: it profits less from more complex models and inclusion of weather data than the Usage Agent. The random forest model learns most from additional data (0.835 to 0.859). The range between best and worst performing model is 0.023 regardless of weather inclusion, which indicates robustness towards algorithmic choice as well as weather. Contrarily, the Usage Agent benefits greatly from weather data. While without the additional data, most models perform around an AUC of 0.7, the inclusion allows for substantial increases towards top performances of 0.93. Especially more complex models (i.e. random forest, XGBoost and partially Adaboost) profit from the inclusion and allow for outperformance of the approach of Riabchuk et al. (forthcoming). We can conclude, that it was not sufficient to either include more complex models or weather data, but the combination of the two additions lead to the substantial performance benefits.
#
# Because random forest and XGBoost perform similar in their respective best setup, we further analyse their AUC over ten households to investigate their stability. The values in Tables 4 and 5 underline the notion, that random forest outperforms XGBoost slightly, but consistently. On average, the XGBoost achieves an AUC of 0.884 over all prediction tasks and devices, while the random forest reaches an AUC of 0.891 on average. The EBM performs similar to the alternatives for the Availability Agent. However, since the Usage Agent is not on par with XGBoost and random forest, we will not consider it as a prediction and explainability approach. Therefore, we decide to apply the random forest with the tuned parameters derived from the grid search.
# <p>
# <center> Table 4: Performances of Random Forest on Ten Households </center>
#
# <style type="text/css">
# .tg  {border-collapse:collapse;border-spacing:0;}
# .tg td{border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;
#   overflow:hidden;padding:10px 5px;word-break:normal;}
# .tg th{border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;
#   font-weight:normal;overflow:hidden;padding:10px 5px;word-break:normal;}
# .tg .tg-0lax{text-align:left;vertical-align:top}
# </style>
# <table class="tg">
# <thead>
#   <tr>
#     <th class="tg-0lax">Household</th>
#     <th class="tg-0lax">Activity</th>
#     <th class="tg-0lax">Usage_TD</th>
#     <th class="tg-0lax">Usage_WM</th>
#     <th class="tg-0lax">Usage_DW</th>
#     <th class="tg-0lax">Usage_WM_2</th>
#     <th class="tg-0lax">Usage_WD</th>
#   </tr>
# </thead>
# <tbody>
#   <tr>
#     <td class="tg-0lax">h1</td>
#     <td class="tg-0lax">0.795</td>
#     <td class="tg-0lax">0.949</td>
#     <td class="tg-0lax">0.923</td>
#     <td class="tg-0lax">0.942</td>
#     <td class="tg-0lax"></td>
#     <td class="tg-0lax"></td>
#   </tr>
#   <tr>
#     <td class="tg-0lax">h2</td>
#     <td class="tg-0lax">0.827</td>
#     <td class="tg-0lax"></td>
#     <td class="tg-0lax">0.892</td>
#     <td class="tg-0lax">0.932</td>
#     <td class="tg-0lax"></td>
#     <td class="tg-0lax"></td>
#   </tr>
#   <tr>
#     <td class="tg-0lax">h3</td>
#     <td class="tg-0lax">0.859</td>
#     <td class="tg-0lax">0.927</td>
#     <td class="tg-0lax">0.934</td>
#     <td class="tg-0lax">0.927</td>
#     <td class="tg-0lax"></td>
#     <td class="tg-0lax"></td>
#   </tr>
#   <tr>
#     <td class="tg-0lax">h4</td>
#     <td class="tg-0lax">0.860</td>
#     <td class="tg-0lax"></td>
#     <td class="tg-0lax">0.929</td>
#     <td class="tg-0lax"></td>
#     <td class="tg-0lax">0.871</td>
#     <td class="tg-0lax"></td>
#   </tr>
#   <tr>
#     <td class="tg-0lax">h5</td>
#     <td class="tg-0lax">0.816</td>
#     <td class="tg-0lax">0.910</td>
#     <td class="tg-0lax"></td>
#     <td class="tg-0lax"></td>
#     <td class="tg-0lax"></td>
#     <td class="tg-0lax"></td>
#   </tr>
#   <tr>
#     <td class="tg-0lax">h6</td>
#     <td class="tg-0lax">0.826</td>
#     <td class="tg-0lax"></td>
#     <td class="tg-0lax">0.914</td>
#     <td class="tg-0lax">0.948</td>
#     <td class="tg-0lax"></td>
#     <td class="tg-0lax"></td>
#   </tr>
#   <tr>
#     <td class="tg-0lax">h7</td>
#     <td class="tg-0lax">0.881</td>
#     <td class="tg-0lax">0.950</td>
#     <td class="tg-0lax">0.945</td>
#     <td class="tg-0lax">0.945</td>
#     <td class="tg-0lax"></td>
#     <td class="tg-0lax"></td>
#   </tr>
#   <tr>
#     <td class="tg-0lax">h8</td>
#     <td class="tg-0lax">0.675</td>
#     <td class="tg-0lax"></td>
#     <td class="tg-0lax">0.921</td>
#     <td class="tg-0lax"></td>
#     <td class="tg-0lax"></td>
#     <td class="tg-0lax"></td>
#   </tr>
#   <tr>
#     <td class="tg-0lax">h9</td>
#     <td class="tg-0lax">0.765</td>
#     <td class="tg-0lax"></td>
#     <td class="tg-0lax">0.926</td>
#     <td class="tg-0lax">0.944</td>
#     <td class="tg-0lax"></td>
#     <td class="tg-0lax">0.920</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax">h10</td>
#     <td class="tg-0lax">0.820</td>
#     <td class="tg-0lax"> </td>
#     <td class="tg-0lax">0.950</td>
#     <td class="tg-0lax"> </td>
#     <td class="tg-0lax"> </td>
#     <td class="tg-0lax"> </td>
#   </tr>
# </tbody>
# </table>
#
#
# <br>
# <p>
# <center> Table 5: Performances of XGBoost on Ten Households </center>
#
# <style type="text/css">
# .tg  {border-collapse:collapse;border-spacing:0;}
# .tg td{border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;
#   overflow:hidden;padding:10px 5px;word-break:normal;}
# .tg th{border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;
#   font-weight:normal;overflow:hidden;padding:10px 5px;word-break:normal;}
# .tg .tg-0lax{text-align:left;vertical-align:top}
# </style>
# <table class="tg">
# <thead>
#   <tr>
#     <th class="tg-0lax">XGBoost</th>
#     <th class="tg-0lax">Activity</th>
#     <th class="tg-0lax">Usage_TD</th>
#     <th class="tg-0lax">Usage_WM</th>
#     <th class="tg-0lax">Usage_DW</th>
#     <th class="tg-0lax">Usage_WM_2</th>
#     <th class="tg-0lax">Usage_WD</th>
#   </tr>
# </thead>
# <tbody>
#   <tr>
#     <td class="tg-0lax">h1</td>
#     <td class="tg-0lax">0.780</td>
#     <td class="tg-0lax">0.927</td>
#     <td class="tg-0lax">0.910</td>
#     <td class="tg-0lax">0.936</td>
#     <td class="tg-0lax"></td>
#     <td class="tg-0lax"></td>
#   </tr>
#   <tr>
#     <td class="tg-0lax">h2</td>
#     <td class="tg-0lax">0.817</td>
#     <td class="tg-0lax"></td>
#     <td class="tg-0lax">0.890</td>
#     <td class="tg-0lax">0.928</td>
#     <td class="tg-0lax"></td>
#     <td class="tg-0lax"></td>
#   </tr>
#   <tr>
#     <td class="tg-0lax">h3</td>
#     <td class="tg-0lax">0.852</td>
#     <td class="tg-0lax">0.922</td>
#     <td class="tg-0lax">0.925</td>
#     <td class="tg-0lax">0.922</td>
#     <td class="tg-0lax"></td>
#     <td class="tg-0lax"></td>
#   </tr>
#   <tr>
#     <td class="tg-0lax">h4</td>
#     <td class="tg-0lax">0.855</td>
#     <td class="tg-0lax"></td>
#     <td class="tg-0lax">0.917</td>
#     <td class="tg-0lax"></td>
#     <td class="tg-0lax">0.860</td>
#     <td class="tg-0lax"></td>
#   </tr>
#   <tr>
#     <td class="tg-0lax">h5</td>
#     <td class="tg-0lax">0.817</td>
#     <td class="tg-0lax">0.905</td>
#     <td class="tg-0lax"></td>
#     <td class="tg-0lax"></td>
#     <td class="tg-0lax"></td>
#     <td class="tg-0lax"></td>
#   </tr>
#   <tr>
#     <td class="tg-0lax">h6</td>
#     <td class="tg-0lax">0.825</td>
#     <td class="tg-0lax"></td>
#     <td class="tg-0lax">0.905</td>
#     <td class="tg-0lax">0.945</td>
#     <td class="tg-0lax"></td>
#     <td class="tg-0lax"></td>
#   </tr>
#   <tr>
#     <td class="tg-0lax">h7</td>
#     <td class="tg-0lax">0.884</td>
#     <td class="tg-0lax">0.943</td>
#     <td class="tg-0lax">0.937</td>
#     <td class="tg-0lax">0.930</td>
#     <td class="tg-0lax"></td>
#     <td class="tg-0lax"></td>
#   </tr>
#   <tr>
#     <td class="tg-0lax">h8</td>
#     <td class="tg-0lax">0.671</td>
#     <td class="tg-0lax"></td>
#     <td class="tg-0lax">0.918</td>
#     <td class="tg-0lax"></td>
#     <td class="tg-0lax"></td>
#     <td class="tg-0lax"></td>
#   </tr>
#   <tr>
#     <td class="tg-0lax">h9</td>
#     <td class="tg-0lax">0.764</td>
#     <td class="tg-0lax"></td>
#     <td class="tg-0lax">0.914</td>
#     <td class="tg-0lax">0.936</td>
#     <td class="tg-0lax"></td>
#     <td class="tg-0lax">0.916</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax">h10</td>
#     <td class="tg-0lax">0.800</td>
#     <td class="tg-0lax"></td>
#     <td class="tg-0lax">0.942</td>
#     <td class="tg-0lax"></td>
#     <td class="tg-0lax"></td>
#     <td class="tg-0lax"></td>
#   </tr>
# </tbody>
# </table>
#
#
# <br>

# %% [markdown]
# ### 5.2 Explainability <a name="Results_explainability" id="Results_Explainability"></a>

# %% [markdown]
# We can look at the results of the explainability evaluation by using
# the saved predictions from LIME and SHAP.
# Exemplarily, we can investigate the outcome of the evaluation of
# logistic regression for the Availabiliy Agent.

# %%
xai= True; weather_sel = True; household_id = 3; model_type = 'logit'
RESULT_PATH = str(EXPORT_PATH)+str(household_id)+ "_" + str(model_type) + "_" + str(model_type) + "_" + str(weather_sel) + "_"

with open(RESULT_PATH + 'predictions.pkl','rb') as path_name:
    predictions_activity = pd.read_pickle(path_name) #pickle.load

# %%
config = json.load(open(EXPORT_PATH + str(household_id) + '_' + str(model_type) + '_' + str(model_type) +'_' + str(weather_sel) +'_config.json', 'r'))
files = ['df.pkl', 'output.pkl']
files = [f"{EXPORT_PATH}{household_id}_{model_type}_{model_type}_{weather_sel}_{file}" for file in files]

# initializing the agent
evaluation = Evaluation_Agent(DATA_PATH,model_type=model_type ,config=config, load_data=True, load_files=files, weather_sel=weather_sel,xai= xai)
evaluation.init_agents()

# %%
xai_scores_activity = evaluation.predictions_to_xai_metrics(predictions_activity)
xai_scores_activity
# Out:
# {'activity_lime_auc_true': 0.8369921090313529,
#  'activity_shap_auc_true': 0.8362111642300767,
#  'activity_lime_auc_pred': 0.9891277041755157,
#  'activity_shap_auc_pred': 1.0,
#  'activity_lime_MAE': 0.02645394363856011,
#  'activity_shap_MAE': 4.47980220168672e-17}

# %% [markdown]
# The same can be done with the usage predictions with the function 'predictions_to_xai_metrics_usage'.
# We display the results of our explainability evaluation in Table 6 and 7 for the Availability and the Usage Agent, respectively.

# %% [markdown]
# <center>Table 6: Results of the Explainability Evaluation for the Availability Agent </center>

# %% [markdown]
# <table style="border-collapse:collapse;border-spacing:0" class="tg"><thead><tr><th style="border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;font-weight:bold;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:bottom;word-break:normal">Availability&nbsp;Agent</th><th style="background-color:#E2EFDA;border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;font-weight:normal;overflow:hidden;padding:10px 5px;text-align:center;vertical-align:bottom;word-break:normal" colspan="4">LIME</th><th style="background-color:#F99;border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;font-weight:normal;overflow:hidden;padding:10px 5px;text-align:center;vertical-align:bottom;word-break:normal" colspan="4">SHAP</th></tr></thead><tbody><tr><td style="border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:bottom;word-break:normal">Model type</td><td style="border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:bottom;word-break:normal">Accuracy</td><td style="border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:bottom;word-break:normal">Fidelity</td><td style="border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:bottom;word-break:normal">MAE</td><td style="border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:bottom;word-break:normal">Duration</td><td style="border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:bottom;word-break:normal">Accuracy</td><td style="border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:bottom;word-break:normal">Fidelity</td><td style="border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:bottom;word-break:normal">MAE</td><td style="border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:bottom;word-break:normal">Duration</td></tr><tr><td style="border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:bottom;word-break:normal">Logit</td><td style="border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:bottom;word-break:normal">0.8371</td><td style="border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:bottom;word-break:normal">0.9890</td><td style="border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:bottom;word-break:normal">0.0265</td><td style="border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:bottom;word-break:normal">73.748</td><td style="border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:bottom;word-break:normal">0.8362</td><td style="border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:bottom;word-break:normal">1</td><td style="border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:bottom;word-break:normal">0</td><td style="border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:bottom;word-break:normal">2.147</td></tr><tr><td style="border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:bottom;word-break:normal">KNN</td><td style="border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:bottom;word-break:normal">0.8295</td><td style="border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:bottom;word-break:normal">0.9747</td><td style="border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:bottom;word-break:normal">0.0194</td><td style="border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:bottom;word-break:normal">79.695</td><td style="border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:bottom;word-break:normal">0.8386</td><td style="border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:bottom;word-break:normal">1</td><td style="border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:bottom;word-break:normal">0</td><td style="border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:bottom;word-break:normal">20.759</td></tr><tr><td style="border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:bottom;word-break:normal">Adaboost</td><td style="border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:bottom;word-break:normal">0.8369</td><td style="border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:bottom;word-break:normal">0.9349</td><td style="border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:bottom;word-break:normal">0.0035</td><td style="border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:bottom;word-break:normal">50.975</td><td style="border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:bottom;word-break:normal">0.8479</td><td style="border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:bottom;word-break:normal">1</td><td style="border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:bottom;word-break:normal">0</td><td style="border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:bottom;word-break:normal">52.103</td></tr><tr><td style="border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:bottom;word-break:normal">Random Forest</td><td style="border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:bottom;word-break:normal">0.8411</td><td style="border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:bottom;word-break:normal">0.9761</td><td style="border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:bottom;word-break:normal">0.0313</td><td style="border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:bottom;word-break:normal">107.363</td><td style="border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:bottom;word-break:normal">0.8451</td><td style="border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:bottom;word-break:normal">1</td><td style="border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:bottom;word-break:normal">0</td><td style="border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:bottom;word-break:normal">64.853</td></tr><tr><td style="border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:bottom;word-break:normal">XGBoost</td><td style="border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:bottom;word-break:normal">0.8378</td><td style="border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:bottom;word-break:normal">0.7971</td><td style="border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:bottom;word-break:normal">0.1848</td><td style="border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:bottom;word-break:normal">310.551</td><td style="border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:bottom;word-break:normal">0.8366</td><td style="border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:bottom;word-break:normal">1</td><td style="border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:bottom;word-break:normal">0</td><td style="border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:bottom;word-break:normal">0.717</td></tr></tbody></table>

# %% [markdown]
# <br>
#
# <center>Table 7: Results of the Explainability Evaluation for the Usage Agent </center>

# %% [markdown]
# <table style="border-collapse:collapse;border-spacing:0" class="tg"><thead><tr><th style="border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;font-weight:bold;overflow:hidden;padding:10px 5px;text-align:center;vertical-align:middle;word-break:normal" rowspan="2">Usage Agent</th><th style="border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;font-weight:normal;overflow:hidden;padding:10px 5px;text-align:center;vertical-align:bottom;word-break:normal" colspan="8">Mean of Devices</th></tr><tr><th style="background-color:#E2EFDA;border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;font-weight:normal;overflow:hidden;padding:10px 5px;text-align:center;vertical-align:bottom;word-break:normal" colspan="4">LIME</th><th style="background-color:#F99;border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;font-weight:normal;overflow:hidden;padding:10px 5px;text-align:center;vertical-align:bottom;word-break:normal" colspan="4">SHAP</th></tr></thead><tbody><tr><td style="border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:bottom;word-break:normal">Model type</td><td style="border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:bottom;word-break:normal">Accuracy</td><td style="border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:bottom;word-break:normal">Fidelity</td><td style="border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:bottom;word-break:normal">MAE</td><td style="border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:bottom;word-break:normal">Duration</td><td style="border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:bottom;word-break:normal">Accuracy</td><td style="border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:bottom;word-break:normal">Fidelity</td><td style="border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:bottom;word-break:normal">MAE</td><td style="border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:bottom;word-break:normal">Duration</td></tr><tr><td style="border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:bottom;word-break:normal">Logit</td><td style="border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:bottom;word-break:normal">0.6761</td><td style="border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:bottom;word-break:normal">0.8215</td><td style="border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:bottom;word-break:normal">0.1454</td><td style="border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:bottom;word-break:normal">2.582</td><td style="border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:bottom;word-break:normal">0.7049</td><td style="border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:bottom;word-break:normal">1</td><td style="border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:bottom;word-break:normal">0</td><td style="border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:bottom;word-break:normal">0.084</td></tr><tr><td style="border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:bottom;word-break:normal">KNN</td><td style="border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:bottom;word-break:normal">0.6928</td><td style="border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:bottom;word-break:normal">0.8101</td><td style="border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:bottom;word-break:normal">0.1858</td><td style="border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:bottom;word-break:normal">2.864</td><td style="border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:bottom;word-break:normal">0.7611</td><td style="border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:bottom;word-break:normal">1</td><td style="border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:bottom;word-break:normal">0</td><td style="border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:bottom;word-break:normal">0.852</td></tr><tr><td style="border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:bottom;word-break:normal">Adaboost</td><td style="border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:bottom;word-break:normal">0.5757</td><td style="border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:bottom;word-break:normal">0.5934</td><td style="border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:bottom;word-break:normal">0.0311</td><td style="border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:bottom;word-break:normal">1.859</td><td style="border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:bottom;word-break:normal">0.8254</td><td style="border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:bottom;word-break:normal">1</td><td style="border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:bottom;word-break:normal">0</td><td style="border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:bottom;word-break:normal">0.813</td></tr><tr><td style="border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:bottom;word-break:normal">Random Forest</td><td style="border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:bottom;word-break:normal">0.7101</td><td style="border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:bottom;word-break:normal">0.7988</td><td style="border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:bottom;word-break:normal">0.1203</td><td style="border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:bottom;word-break:normal">3.682</td><td style="border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:bottom;word-break:normal">0.8726</td><td style="border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:bottom;word-break:normal">1</td><td style="border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:bottom;word-break:normal">0</td><td style="border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:bottom;word-break:normal">0.957</td></tr><tr><td style="border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:bottom;word-break:normal">XGBoost</td><td style="border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:bottom;word-break:normal">0.6763</td><td style="border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:bottom;word-break:normal">0.6516</td><td style="border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:bottom;word-break:normal">0.2705</td><td style="border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:bottom;word-break:normal">10.222</td><td style="border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:bottom;word-break:normal">0.9353</td><td style="border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:bottom;word-break:normal">1</td><td style="border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:bottom;word-break:normal">0</td><td style="border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:bottom;word-break:normal">0.230</td></tr></tbody></table>

# %% [markdown]
# We can see that SHAP is generally performing better according to the higher accuracy and the fidelity compared to LIME. Most strikingly, since the predictions of the prediction algorithms and of SHAP are so similar, the fidelity is perfect, i.e. SHAP works very well for mimicing the local behavior of the prediction model. This is also reflected in the MAE which is almost zero for SHAP. The concrete values are not displayed as they are
# too small.
#
# The predictions of LIME for the Usage Agent are performing quite badly. This is because the predictions e.g. for Adaboost
# are all very close to the chosen cutoff of 0.5 to create target values of the prediction. Although LIME is only off on average about 0.0311 it sometimes exceeds the cutoff assigning it to the wrong class. For the Availability Agent, the worse calibration of LIME does not take too much influence since the values from the prediction are more extreme.
#
# Moreover, for most cases SHAP creates the predictions faster than LIME. Especially, LIME is not able to handle
# xgboost very well while the TreeExplainer of SHAP used for xgboost really gives excellent runtime. Note that the durations are only comparable within the model since the evaluation was run on different machines with different background tasks that slowed down the evaluation at times.
#
# Overall, since there is no significant difference between the fidelity of SHAP between the models we will apply SHAP with one of the most accurate algorithms while also minimizing runtime.
#
# Since xgboost and random forest perform similary regarding predictive performance for the Availability Agent we have also run the evaluation with the treeExplainer for random forest. The resulting runtime (Availability: 0.558, Usage: 0.0357) are also very low while there was little change with regards to our metrics.
# We therefore recommend the usage of random forest with the TreeExplainer as our final model.

# %% [markdown]
# ### 5.3 Final Recommendation <a name="Final_rec" id="Final_rec"></a>
#
# Now that we have decided on using random forest and SHAP to derive our
# predictions, let's look a little closer on how the sentences that explain the predictions
# is derived.
#
# In the function 'visualize_recommendation' from the Recommendation Agent we use the function "explanation_from_feature_importance" with an individual configuration for each agent.
# The necessary inputs to that function are the feature importances from the
# recommendation table that are derived beforehand.
# This function uses the SV to create an importance ranking which is now used for the final explanation.
#
# We seperate the features in two categories for each of the to-be-explained agents:
#
# **Features based on weather data** The 5 weather features that are presented above are derived from an additional dataframe
#  since the values in the dataframes are scaled for the prediction. They are part of both agents and
#  recommendation without restrictions.
#
# **Non-weather features**
#
# - Availability: The explanation is derived from the feature
# importances for 'recent activity in
#  last 24/4/72 hours'.  We only display the most important feature to shorten the explanation. Additionally, if the values are positive the temporal features (hour, day) are also returned.
#
#
# - Usage: For usage we take the feature "activity in last two days" and the highest ranking usage lag feature (device used last day, device used two days ago).
#
# The sentence takes out the two most important featuers of each group and embedds them
# in a sentence. The usage explanation is provided for each device (if a recommendation is given)
# since their predictions differ.

# %% [markdown]
# Additionally, if the user would like to know more about the specific
# impact of the feature they can be supplied the plots provided by SHAP.

# %%
recommend.visualize_recommendation(table, price, diagnostics=True)
# Out:
# There is no recommendation for the device Tumble Dryer .
# There is no recommendation for the device Washing Machine .
# You have a recommendation for the following device: Dishwasher
#
# Please use the device on the 21.08.2014 at 12:00 o'clock because it saves you 8.73 % of costs compared to the mean of the day.
#
# We believe you are likely to use the device in the near future since you were active during the last 2 days and have used the device in the last two days.The weather conditions (windspeed:21.39, wind direction:227.2) support that recommendation.
# Vizualizations for further insights into our predictions:
# <div id='i8KIHGG11HA6HPTY1PRLR'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
# ...

# %% [markdown]
# ## 6. Discussion <a name="Discussion" id="Discussion"></a>
#
# Our results show a substantial increase in performance, while at the same time opening up the “black box” of the recommendations. We provide users with comprehensive, understandable and persuasive explanations to achieve behavioral change with regard to energy efficiency. Therefore our contribution is two-fold: first, we address performance problems previously prevalent in the approach of Riabchuk et al. (forthcoming) and second, the research gap identified by Himeur et al. (2021) with regards to explainability in recommender systems is tackled. The results show promising implications for optimizing overall energy load through application of artificial intelligence in the building and smart home sector.
#
# While we manage to achieve substantial contribution, several limitations still exists. We exemplarily apply three different explainability approaches, while a multitude of methods that we present in Section 2 exist. Most modern algorithms also suffer from poorly managed repositories. Still, we cover a few different algorithms to display advantages and possibilities of explainability. Second, we evaluate explainability with regard to its accuracy as a part of fidelity. Potentially, clarity and completeness of fidelity should also be assessed (Zhou et al., 2021). Furthermore, we do not evaluate interpretability, comprehensibility and understandability as we lack user feedback. This should be focus of further research.
#
# Further topics that would benefit from additional research, are discussed in the following. First, expanding the data base with additional information about the user and the human-recommender system interaction and applying generalized additive model with manifest and latent interactions (GAMMLI) introduced by Guo et. al. (2020) could deliver interesting results. This model is intrinsically interpretable, additively consists of the user and item main effects, the manifest user-item interactions based on observed features, and the latent interaction effects from residuals. It is beneficial for enhancing the model interpretability, and can also facilitate the cold-start recommendation problem. Second, try out Neural Networks to detect certain patterns in user behavior. In order to tackle the lack of interpretability, which is an inevitable problem when using neural network models in real applications, Yang et al. (2021) introduced an explainable neural network based on generalized additive models with structured interactions (GAMI-Net). It is proposed to pursue a good balance between prediction accuracy and model interpretability. GAMI-Net is a disentangled feedforward network with multiple additive subnetworks where each subnetwork consists of multiple hidden layers and is designed for capturing one main effect or one pairwise interaction. Further, expanding the recommender system to provide the user with several recommendations per day to model the reality more truthfully, would be an aspect to address further.

# %% [markdown]
# ## 7. Conclusion  <a name="Conclusion" id="Conclusion"></a>
#
# The research on explainability in recommender systems, especially in the smart home area, is very limited. We adapt an existing approach by Riabchuk et al. (forthcoming), that addresses demand response and load shifting, and extend it by enhancing the predictive capacity and adding explainable recommendations in textual and visual manner. We achieve this by applying a multi-agent model, testing out state-of-the-art algorithms and their hyperparameters, as well as investigating multiple explainability approaches - including model-agnostic as well as model-intrinsic ones. We provide an overview of predictive and explainability performance, that is able to supply information for a deployable recommender system. This might lead to substantial increases in persuasiveness of the recommendations, and therefore delivers valuable contributions to both research as well as practical energy efficiency applications.

# %% [markdown]
# ## References <a name="References" id="References"></a>
#
# Alsalemi, A., Sardianos, C., Bensaali, F., Varlamis, I., Amira, A., & Dimitrakopoulos, G. (2019). The role of micro-moments: A survey of habitual behavior change and recommender systems for energy saving. *IEEE Systems Journal, 13*(3), 3376-3387.
#
# Alvarez-Melis, D., & Jaakkola, T. S. (2018). On the robustness of interpretability methods. *arXiv preprint arXiv:1806.08049*.
#
# Bodria, F., Giannotti, F., Guidotti, R., Naretto, F., Pedreschi, D., & Rinzivillo, S. (2021). Benchmarking and survey of explanation methods for black box models. *arXiv preprint arXiv:2102.13076*.
#
# Breiman, L. (2001). Random forests. *Machine learning, 45*(1), 5-32.
#
# Carvalho, D. V., Pereira, E. M., & Cardoso, J. S. (2019). Machine learning interpretability: A survey on methods and metrics. *Electronics, 8*(8), 832.
#
# Chen, T., & Guestrin, C. (2016, August). Xgboost: A scalable tree boosting system. In *Proceedings of the 22nd acm sigkdd international conference on knowledge discovery and data mining* (pp. 785-794)
#
# Cramer, H., Evers, V., Ramlal, S., Van Someren, M., Rutledge, L., Stash, N., ... & Wielinga, B. (2008). The effects of transparency on trust in and acceptance of a content-based art recommender. *User modeling and user-adapted interaction, 18*(5), 455.
#
# Cunningham, P., & Delany, S. J. (2020). k-Nearest neighbour classifiers: (with Python examples). *arXiv preprint arXiv:2004.04523*.
#
# Dieber, J., & Kirrane, S. (2020). Why model why? Assessing the strengths and limitations of LIME. *arXiv preprint arXiv:2012.00093*.
#
# Doshi-Velez, F., & Kim, B. (2017). Towards a rigorous science of interpretable machine learning. *arXiv preprint arXiv:1702.08608*.
#
# Economidou, M., Todeschi, V., Bertoldi, P., Agostino, D. D., Zangheri, P., & Castellazzi, L. (2020). Review of 50 years of EU energy efficiency policies for buildings. *Energy and buildings*, 110322.
#
# Fraternali, P., Herrera, S., Novak, J., Melenhorst, M., Tzovaras, D., Krinidis, S., ... & Cellina, F. (2017, June). enCOMPASS—An integrative approach to behavioural change for energy saving. In *2017 Global Internet of Things Summit (GIoTS)* (pp. 1-6). IEEE.
#
# Freund, Y., & Schapire, R. E. (1997). A decision-theoretic generalization of on-line learning and an application to boosting. *Journal of computer and system sciences, 55*(1), 119-139.
#
# Guo, Y., Su, Y., Yang, Z., & Zhang, A. (2020). Explainable recommendation systems by generalized additive models with manifest and latent interactions. *arXiv preprint arXiv:2012.08196*.
#
# Himeur, Y., Alsalemi, A., Al-Kababji, A., Bensaali, F., Amira, A., Sardianos, C., ... & Varlamis, I. (2021). A survey of recommender systems for energy efficiency in buildings: Principles, challenges and prospects. *Information fusion, 72*, 1-21.
#
# Jiménez-Bravo, D. M., Pérez-Marcos, J., H De la Iglesia, D., Villarrubia González, G., & De Paz, J. F. (2019). Multi-agent recommendation system for electrical energy optimization and cost saving in smart homes. *Energies, 12*(7), 1317.
#
# Lakkaraju, H., Kamar, E., Caruana, R., & Leskovec, J. (2017). Interpretable & explorable approximations of black box models. *arXiv preprint arXiv:1707.01154*.
#
# Lakkaraju, H., Kamar, E., Caruana, R., & Leskovec, J. (2019, January). Faithful and customizable explanations of black box models. In *Proceedings of the 2019 aaai/acm conference on ai, ethics, and society* (pp. 131-138).
#
# Lou, Y., Caruana, R., Gehrke, J., & Hooker, G. (2013, August). Accurate intelligible models with pairwise interactions. In *Proceedings of the 19th acm sigkdd international conference on knowledge discovery and data mining* (pp. 623-631).
#
# Lundberg, S. M., & Lee, S. I. (2017, December). A unified approach to interpreting model predictions. In *Proceedings of the 31st international conference on neural information processing systems* (pp. 4768-4777).
#
# Lundberg, S. M., Erion, G., Chen, H., DeGrave, A., Prutkin, J. M., Nair, B., ... & Lee, S. I. (2020). From local explanations to global understanding with explainable AI for trees. *Nature machine intelligence, 2*(1), 56-67.
#
# Molnar, C. (2021). *Interpretable machine learning*. Leanpub.
#
# Nori, H., Jenkins, S., Koch, P., & Caruana, R. (2019). Interpretml: A unified framework for machine learning interpretability. *arXiv preprint arXiv:1909.09223*.
#
# Peng, C. Y. J., Lee, K. L., & Ingersoll, G. M. (2002). An introduction to logistic regression analysis and reporting. *The journal of educational research, 96*(1), 3-14.
#
# Plumb, G., Molitor, D., & Talwalkar, A. (2018). Model agnostic supervised local explanations. *arXiv preprint arXiv:1807.02910*.
#
# Riabchuk et al. (forthcoming). *Utility-based context-aware multi-agent recommendation system for energy efficiency in residential buildings*. Preprint.
#
# Ribeiro, Singh, Guestrin. (2016). "Why should I trust you?" Explaining the predictions of any classifier. In *Proceedings of the 22nd acm sigkdd international conference on knowledge discovery and data mining* (pp. 1135–1144).
#
# Robnik-Šikonja, M., & Bohanec, M. (2018). Perturbation-based explanations of prediction models. In *Human and machine learning* (pp. 159-175). Springer, Cham.
#
# Sardianos, C., Varlamis, I., Chronis, C., Dimitrakopoulos, G., Alsalemi, A., Himeur, Y., ... & Amira, A. (2021). The emergence of explainability of intelligent systems: Delivering explainable and personalized recommendations for energy efficiency. *International journal of intelligent systems, 36*(2), 656-680.
#
# Shigeyoshi, H., Tamano, K. I., Saga, R., Tsuji, H., Inoue, S., & Ueno, T. (2013, July). Social experiment on advisory recommender system for energy-saving. In *International conference on human interface and the management of information* (pp. 545-554).
#
# Singh, Sengupta, Lakshminarayanan. (2020). Explainable deep learning models in medical image analysis. *Journal of imaging, 6*(6), 52.
#
# Wei, P., Xia, S., & Jiang, X. (2018, July). Energy saving recommendations and user location modeling in commercial buildings. In *Proceedings of the 26th conference on user modeling, adaptation and personalization* (pp. 3-11).
#
# Yang, Z., Zhang, A., & Sudjianto, A. (2021). GAMI-Net: An explainable neural network based on generalized additive models with structured interactions. *Pattern recognition, 120*, 108192.
#
# Zhang, Y., & Chen, X. (2020). Explainable recommendation: A survey and new perspectives. *Foundations and trends in information retrieval, 14*(1), 1-101.
#
# Zhou, J., Gandomi, A. H., Chen, F., & Holzinger, A. (2021). Evaluating the quality of machine learning explanations: A survey on methods and metrics. *Electronics, 10*(5), 593.

# %% [markdown]
# ## Appendix <a name="Appendix" id="Appendix"></a>
# ### With Weather Data:
# <style type="text/css">
# .tg  {border-collapse:collapse;border-spacing:0;}
# .tg td{border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;
#   overflow:hidden;padding:10px 5px;word-break:normal;}
# .tg th{border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;
#   font-weight:normal;overflow:hidden;padding:10px 5px;word-break:normal;}
# .tg .tg-za14{border-color:inherit;text-align:left;vertical-align:bottom}
# </style>
# <table class="tg">
# <thead>
#   <tr>
#     <th class="tg-za14">Logit</th>
#     <th class="tg-za14">max_iter</th>
#     <th class="tg-za14">Availability</th>
#     <th class="tg-za14">Usage_TD</th>
#     <th class="tg-za14">Usage_WM</th>
#     <th class="tg-za14">Usage_DW</th>
#   </tr>
# </thead>
# <tbody>
#   <tr>
#     <td class="tg-za14"></td>
#     <td class="tg-za14">10</td>
#     <td class="tg-za14">0.836</td>
#     <td class="tg-za14">0.725</td>
#     <td class="tg-za14">0.700</td>
#     <td class="tg-za14">0.683</td>
#   </tr>
#   <tr>
#     <td class="tg-za14"></td>
#     <td class="tg-za14">100</td>
#     <td class="tg-za14">0.836</td>
#     <td class="tg-za14">0.728</td>
#     <td class="tg-za14">0.703</td>
#     <td class="tg-za14">0.684</td>
#   </tr>
#   <tr>
#     <td class="tg-za14"></td>
#     <td class="tg-za14">1000</td>
#     <td class="tg-za14">0.836</td>
#     <td class="tg-za14">0.728</td>
#     <td class="tg-za14">0.703</td>
#     <td class="tg-za14">0.684</td>
#   </tr>
# </tbody>
# </table>
#
# <style type="text/css">
# .tg  {border-collapse:collapse;border-spacing:0;}
# .tg td{border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;
#   overflow:hidden;padding:10px 5px;word-break:normal;}
# .tg th{border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;
#   font-weight:normal;overflow:hidden;padding:10px 5px;word-break:normal;}
# .tg .tg-0lax{text-align:left;vertical-align:top}
# </style>
# <table class="tg">
# <thead>
#   <tr>
#     <th class="tg-0lax">Random Forest</th>
#     <th class="tg-0lax">max_depth</th>
#     <th class="tg-0lax">n_estimators</th>
#     <th class="tg-0lax">max_features</th>
#     <th class="tg-0lax">Availability</th>
#     <th class="tg-0lax">Usage_TD</th>
#     <th class="tg-0lax">Usage_WM</th>
#     <th class="tg-0lax">Usage_DW</th>
#   </tr>
# </thead>
# <tbody>
#   <tr>
#     <td class="tg-0lax"></td>
#     <td class="tg-0lax">5</td>
#     <td class="tg-0lax">100</td>
#     <td class="tg-0lax">auto</td>
#     <td class="tg-0lax">0.853</td>
#     <td class="tg-0lax">0.861</td>
#     <td class="tg-0lax">0.871</td>
#     <td class="tg-0lax">0.880</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax"></td>
#     <td class="tg-0lax">5</td>
#     <td class="tg-0lax">100</td>
#     <td class="tg-0lax">sqrt</td>
#     <td class="tg-0lax">0.854</td>
#     <td class="tg-0lax">0.860</td>
#     <td class="tg-0lax">0.874</td>
#     <td class="tg-0lax">0.880</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax"></td>
#     <td class="tg-0lax">5</td>
#     <td class="tg-0lax">100</td>
#     <td class="tg-0lax">log2</td>
#     <td class="tg-0lax">0.854</td>
#     <td class="tg-0lax">0.867</td>
#     <td class="tg-0lax">0.868</td>
#     <td class="tg-0lax">0.880</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax"></td>
#     <td class="tg-0lax">5</td>
#     <td class="tg-0lax">500</td>
#     <td class="tg-0lax">auto</td>
#     <td class="tg-0lax">0.854</td>
#     <td class="tg-0lax">0.862</td>
#     <td class="tg-0lax">0.875</td>
#     <td class="tg-0lax">0.884</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax"></td>
#     <td class="tg-0lax">5</td>
#     <td class="tg-0lax">500</td>
#     <td class="tg-0lax">sqrt</td>
#     <td class="tg-0lax">0.854</td>
#     <td class="tg-0lax">0.864</td>
#     <td class="tg-0lax">0.876</td>
#     <td class="tg-0lax">0.885</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax"></td>
#     <td class="tg-0lax">5</td>
#     <td class="tg-0lax">500</td>
#     <td class="tg-0lax">log2</td>
#     <td class="tg-0lax">0.854</td>
#     <td class="tg-0lax">0.867</td>
#     <td class="tg-0lax">0.875</td>
#     <td class="tg-0lax">0.886</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax"></td>
#     <td class="tg-0lax">5</td>
#     <td class="tg-0lax">1000</td>
#     <td class="tg-0lax">auto</td>
#     <td class="tg-0lax">0.854</td>
#     <td class="tg-0lax">0.862</td>
#     <td class="tg-0lax">0.874</td>
#     <td class="tg-0lax">0.884</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax"></td>
#     <td class="tg-0lax">5</td>
#     <td class="tg-0lax">1000</td>
#     <td class="tg-0lax">sqrt</td>
#     <td class="tg-0lax">0.854</td>
#     <td class="tg-0lax">0.864</td>
#     <td class="tg-0lax">0.874</td>
#     <td class="tg-0lax">0.884</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax"></td>
#     <td class="tg-0lax">5</td>
#     <td class="tg-0lax">1000</td>
#     <td class="tg-0lax">log2</td>
#     <td class="tg-0lax">0.854</td>
#     <td class="tg-0lax">0.865</td>
#     <td class="tg-0lax">0.875</td>
#     <td class="tg-0lax">0.886</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax"></td>
#     <td class="tg-0lax">10</td>
#     <td class="tg-0lax">100</td>
#     <td class="tg-0lax">auto</td>
#     <td class="tg-0lax">0.858</td>
#     <td class="tg-0lax">0.928</td>
#     <td class="tg-0lax">0.930</td>
#     <td class="tg-0lax">0.923</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax"></td>
#     <td class="tg-0lax">10</td>
#     <td class="tg-0lax">100</td>
#     <td class="tg-0lax">sqrt</td>
#     <td class="tg-0lax">0.858</td>
#     <td class="tg-0lax">0.930</td>
#     <td class="tg-0lax">0.929</td>
#     <td class="tg-0lax">0.929</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax"></td>
#     <td class="tg-0lax">10</td>
#     <td class="tg-0lax">100</td>
#     <td class="tg-0lax">log2</td>
#     <td class="tg-0lax">0.858</td>
#     <td class="tg-0lax">0.928</td>
#     <td class="tg-0lax">0.929</td>
#     <td class="tg-0lax">0.923</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax"></td>
#     <td class="tg-0lax">10</td>
#     <td class="tg-0lax">500</td>
#     <td class="tg-0lax">auto</td>
#     <td class="tg-0lax">0.859</td>
#     <td class="tg-0lax">0.927</td>
#     <td class="tg-0lax">0.933</td>
#     <td class="tg-0lax">0.930</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax"></td>
#     <td class="tg-0lax">10</td>
#     <td class="tg-0lax">500</td>
#     <td class="tg-0lax">sqrt</td>
#     <td class="tg-0lax">0.859</td>
#     <td class="tg-0lax">0.928</td>
#     <td class="tg-0lax">0.934</td>
#     <td class="tg-0lax">0.927</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax"></td>
#     <td class="tg-0lax">10</td>
#     <td class="tg-0lax">500</td>
#     <td class="tg-0lax">log2</td>
#     <td class="tg-0lax">0.859</td>
#     <td class="tg-0lax">0.928</td>
#     <td class="tg-0lax">0.932</td>
#     <td class="tg-0lax">0.928</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax"></td>
#     <td class="tg-0lax">10</td>
#     <td class="tg-0lax">1000</td>
#     <td class="tg-0lax">auto</td>
#     <td class="tg-0lax">0.859</td>
#     <td class="tg-0lax">0.927</td>
#     <td class="tg-0lax">0.932</td>
#     <td class="tg-0lax">0.926</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax"></td>
#     <td class="tg-0lax">10</td>
#     <td class="tg-0lax">1000</td>
#     <td class="tg-0lax">sqrt</td>
#     <td class="tg-0lax">0.859</td>
#     <td class="tg-0lax">0.928</td>
#     <td class="tg-0lax">0.932</td>
#     <td class="tg-0lax">0.929</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax"></td>
#     <td class="tg-0lax">10</td>
#     <td class="tg-0lax">1000</td>
#     <td class="tg-0lax">log2</td>
#     <td class="tg-0lax">0.859</td>
#     <td class="tg-0lax">0.929</td>
#     <td class="tg-0lax">0.933</td>
#     <td class="tg-0lax">0.928</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax"></td>
#     <td class="tg-0lax">20</td>
#     <td class="tg-0lax">100</td>
#     <td class="tg-0lax">auto</td>
#     <td class="tg-0lax">0.853</td>
#     <td class="tg-0lax">0.931</td>
#     <td class="tg-0lax">0.932</td>
#     <td class="tg-0lax">0.928</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax"></td>
#     <td class="tg-0lax">20</td>
#     <td class="tg-0lax">100</td>
#     <td class="tg-0lax">sqrt</td>
#     <td class="tg-0lax">0.853</td>
#     <td class="tg-0lax">0.931</td>
#     <td class="tg-0lax">0.930</td>
#     <td class="tg-0lax">0.929</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax"></td>
#     <td class="tg-0lax">20</td>
#     <td class="tg-0lax">100</td>
#     <td class="tg-0lax">log2</td>
#     <td class="tg-0lax">0.853</td>
#     <td class="tg-0lax">0.932</td>
#     <td class="tg-0lax">0.935</td>
#     <td class="tg-0lax">0.929</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax"></td>
#     <td class="tg-0lax">20</td>
#     <td class="tg-0lax">500</td>
#     <td class="tg-0lax">auto</td>
#     <td class="tg-0lax">0.854</td>
#     <td class="tg-0lax">0.931</td>
#     <td class="tg-0lax">0.935</td>
#     <td class="tg-0lax">0.931</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax"></td>
#     <td class="tg-0lax">20</td>
#     <td class="tg-0lax">500</td>
#     <td class="tg-0lax">sqrt</td>
#     <td class="tg-0lax">0.854</td>
#     <td class="tg-0lax">0.932</td>
#     <td class="tg-0lax">0.934</td>
#     <td class="tg-0lax">0.929</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax"></td>
#     <td class="tg-0lax">20</td>
#     <td class="tg-0lax">500</td>
#     <td class="tg-0lax">log2</td>
#     <td class="tg-0lax">0.854</td>
#     <td class="tg-0lax">0.930</td>
#     <td class="tg-0lax">0.934</td>
#     <td class="tg-0lax">0.930</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax"></td>
#     <td class="tg-0lax">20</td>
#     <td class="tg-0lax">1000</td>
#     <td class="tg-0lax">auto</td>
#     <td class="tg-0lax">0.854</td>
#     <td class="tg-0lax">0.931</td>
#     <td class="tg-0lax">0.935</td>
#     <td class="tg-0lax">0.929</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax"></td>
#     <td class="tg-0lax">20</td>
#     <td class="tg-0lax">1000</td>
#     <td class="tg-0lax">sqrt</td>
#     <td class="tg-0lax">0.855</td>
#     <td class="tg-0lax">0.931</td>
#     <td class="tg-0lax">0.935</td>
#     <td class="tg-0lax">0.928</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax"></td>
#     <td class="tg-0lax">20</td>
#     <td class="tg-0lax">1000</td>
#     <td class="tg-0lax">log2</td>
#     <td class="tg-0lax">0.854</td>
#     <td class="tg-0lax">0.931</td>
#     <td class="tg-0lax">0.934</td>
#     <td class="tg-0lax">0.931</td>
#   </tr>
# </tbody>
# </table>
#
# <style type="text/css">
# .tg  {border-collapse:collapse;border-spacing:0;}
# .tg td{border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;
#   overflow:hidden;padding:10px 5px;word-break:normal;}
# .tg th{border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;
#   font-weight:normal;overflow:hidden;padding:10px 5px;word-break:normal;}
# .tg .tg-0lax{text-align:left;vertical-align:top}
# </style>
# <table class="tg">
# <thead>
#   <tr>
#     <th class="tg-0lax">Adaboost</th>
#     <th class="tg-0lax">learning_rate</th>
#     <th class="tg-0lax">n_estimators</th>
#     <th class="tg-0lax">Availability</th>
#     <th class="tg-0lax">Usage_TD</th>
#     <th class="tg-0lax">Usage_WM</th>
#     <th class="tg-0lax">Usage_DW</th>
#   </tr>
# </thead>
# <tbody>
#   <tr>
#     <td class="tg-0lax"></td>
#     <td class="tg-0lax">0.001</td>
#     <td class="tg-0lax">50</td>
#     <td class="tg-0lax">0.756</td>
#     <td class="tg-0lax">0.686</td>
#     <td class="tg-0lax">0.636</td>
#     <td class="tg-0lax">0.673</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax"></td>
#     <td class="tg-0lax">0.001</td>
#     <td class="tg-0lax">100</td>
#     <td class="tg-0lax">0.756</td>
#     <td class="tg-0lax">0.699</td>
#     <td class="tg-0lax">0.641</td>
#     <td class="tg-0lax">0.681</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax"></td>
#     <td class="tg-0lax">0.001</td>
#     <td class="tg-0lax">500</td>
#     <td class="tg-0lax">0.817</td>
#     <td class="tg-0lax">0.705</td>
#     <td class="tg-0lax">0.707</td>
#     <td class="tg-0lax">0.709</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax"></td>
#     <td class="tg-0lax">0.01</td>
#     <td class="tg-0lax">50</td>
#     <td class="tg-0lax">0.817</td>
#     <td class="tg-0lax">0.706</td>
#     <td class="tg-0lax">0.707</td>
#     <td class="tg-0lax">0.709</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax"></td>
#     <td class="tg-0lax">0.01</td>
#     <td class="tg-0lax">100</td>
#     <td class="tg-0lax">0.833</td>
#     <td class="tg-0lax">0.708</td>
#     <td class="tg-0lax">0.720</td>
#     <td class="tg-0lax">0.715</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax"></td>
#     <td class="tg-0lax">0.01</td>
#     <td class="tg-0lax">500</td>
#     <td class="tg-0lax">0.847</td>
#     <td class="tg-0lax">0.758</td>
#     <td class="tg-0lax">0.755</td>
#     <td class="tg-0lax">0.770</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax"></td>
#     <td class="tg-0lax">0.1</td>
#     <td class="tg-0lax">50</td>
#     <td class="tg-0lax">0.847</td>
#     <td class="tg-0lax">0.758</td>
#     <td class="tg-0lax">0.759</td>
#     <td class="tg-0lax">0.770</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax"></td>
#     <td class="tg-0lax">0.1</td>
#     <td class="tg-0lax">100</td>
#     <td class="tg-0lax">0.850</td>
#     <td class="tg-0lax">0.779</td>
#     <td class="tg-0lax">0.777</td>
#     <td class="tg-0lax">0.788</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax"></td>
#     <td class="tg-0lax">0.1</td>
#     <td class="tg-0lax">500</td>
#     <td class="tg-0lax">0.850</td>
#     <td class="tg-0lax">0.809</td>
#     <td class="tg-0lax">0.811</td>
#     <td class="tg-0lax">0.831</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax"></td>
#     <td class="tg-0lax">1.0</td>
#     <td class="tg-0lax">50</td>
#     <td class="tg-0lax">0.848</td>
#     <td class="tg-0lax">0.819</td>
#     <td class="tg-0lax">0.822</td>
#     <td class="tg-0lax">0.835</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax"></td>
#     <td class="tg-0lax">1.0</td>
#     <td class="tg-0lax">100</td>
#     <td class="tg-0lax">0.849</td>
#     <td class="tg-0lax">0.825</td>
#     <td class="tg-0lax">0.835</td>
#     <td class="tg-0lax">0.851</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax"></td>
#     <td class="tg-0lax">1.0</td>
#     <td class="tg-0lax">500</td>
#     <td class="tg-0lax">0.846</td>
#     <td class="tg-0lax">0.835</td>
#     <td class="tg-0lax">0.849</td>
#     <td class="tg-0lax">0.864</td>
#   </tr>
# </tbody>
# </table>
#
# <style type="text/css">
# .tg  {border-collapse:collapse;border-spacing:0;}
# .tg td{border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;
#   overflow:hidden;padding:10px 5px;word-break:normal;}
# .tg th{border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;
#   font-weight:normal;overflow:hidden;padding:10px 5px;word-break:normal;}
# .tg .tg-0lax{text-align:left;vertical-align:top}
# </style>
# <table class="tg">
# <thead>
#   <tr>
#     <th class="tg-0lax">KNN</th>
#     <th class="tg-0lax">leaf_size</th>
#     <th class="tg-0lax">n_neighbors</th>
#     <th class="tg-0lax">Availability</th>
#     <th class="tg-0lax">Usage_TD</th>
#     <th class="tg-0lax">Usage_WM</th>
#     <th class="tg-0lax">Usage_DW</th>
#   </tr>
# </thead>
# <tbody>
#   <tr>
#     <td class="tg-0lax"></td>
#     <td class="tg-0lax">30</td>
#     <td class="tg-0lax">1</td>
#     <td class="tg-0lax">0.712</td>
#     <td class="tg-0lax">0.933</td>
#     <td class="tg-0lax">0.941</td>
#     <td class="tg-0lax">0.966</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax"></td>
#     <td class="tg-0lax">30</td>
#     <td class="tg-0lax">5</td>
#     <td class="tg-0lax">0.812</td>
#     <td class="tg-0lax">0.800</td>
#     <td class="tg-0lax">0.811</td>
#     <td class="tg-0lax">0.834</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax"></td>
#     <td class="tg-0lax">30</td>
#     <td class="tg-0lax">10</td>
#     <td class="tg-0lax">0.830</td>
#     <td class="tg-0lax">0.760</td>
#     <td class="tg-0lax">0.758</td>
#     <td class="tg-0lax">0.785</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax"></td>
#     <td class="tg-0lax">60</td>
#     <td class="tg-0lax">1</td>
#     <td class="tg-0lax">0.712</td>
#     <td class="tg-0lax">0.938</td>
#     <td class="tg-0lax">0.934</td>
#     <td class="tg-0lax">0.963</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax"></td>
#     <td class="tg-0lax">60</td>
#     <td class="tg-0lax">5</td>
#     <td class="tg-0lax">0.812</td>
#     <td class="tg-0lax">0.807</td>
#     <td class="tg-0lax">0.811</td>
#     <td class="tg-0lax">0.832</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax"></td>
#     <td class="tg-0lax">60</td>
#     <td class="tg-0lax">10</td>
#     <td class="tg-0lax">0.830</td>
#     <td class="tg-0lax">0.760</td>
#     <td class="tg-0lax">0.760</td>
#     <td class="tg-0lax">0.775</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax"></td>
#     <td class="tg-0lax">90</td>
#     <td class="tg-0lax">1</td>
#     <td class="tg-0lax">0.712</td>
#     <td class="tg-0lax">0.934</td>
#     <td class="tg-0lax">0.940</td>
#     <td class="tg-0lax">0.953</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax"></td>
#     <td class="tg-0lax">90</td>
#     <td class="tg-0lax">5</td>
#     <td class="tg-0lax">0.812</td>
#     <td class="tg-0lax">0.806</td>
#     <td class="tg-0lax">0.811</td>
#     <td class="tg-0lax">0.831</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax"></td>
#     <td class="tg-0lax">90</td>
#     <td class="tg-0lax">10</td>
#     <td class="tg-0lax">0.830</td>
#     <td class="tg-0lax">0.758</td>
#     <td class="tg-0lax">0.764</td>
#     <td class="tg-0lax">0.775</td>
#   </tr>
# </tbody>
# </table>
#
# <style type="text/css">
# .tg  {border-collapse:collapse;border-spacing:0;}
# .tg td{border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;
#   overflow:hidden;padding:10px 5px;word-break:normal;}
# .tg th{border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;
#   font-weight:normal;overflow:hidden;padding:10px 5px;word-break:normal;}
# .tg .tg-0lax{text-align:left;vertical-align:top}
# </style>
# <table class="tg">
# <thead>
#   <tr>
#     <th class="tg-0lax">XGBoost</th>
#     <th class="tg-0lax">learning_rate</th>
#     <th class="tg-0lax">max_depth</th>
#     <th class="tg-0lax">lambda</th>
#     <th class="tg-0lax">alpha</th>
#     <th class="tg-0lax">Availability</th>
#     <th class="tg-0lax">Usage_TD</th>
#     <th class="tg-0lax">Usage_WM</th>
#     <th class="tg-0lax">Usage_DW</th>
#   </tr>
# </thead>
# <tbody>
#   <tr>
#     <td class="tg-0lax"></td>
#     <td class="tg-0lax">0.01</td>
#     <td class="tg-0lax">6</td>
#     <td class="tg-0lax">0.0</td>
#     <td class="tg-0lax">1.0</td>
#     <td class="tg-0lax">0.850</td>
#     <td class="tg-0lax">0.844</td>
#     <td class="tg-0lax">0.832</td>
#     <td class="tg-0lax">0.844</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax"></td>
#     <td class="tg-0lax">0.01</td>
#     <td class="tg-0lax">6</td>
#     <td class="tg-0lax">0.5</td>
#     <td class="tg-0lax">0.5</td>
#     <td class="tg-0lax">0.850</td>
#     <td class="tg-0lax">0.856</td>
#     <td class="tg-0lax">0.840</td>
#     <td class="tg-0lax">0.847</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax"></td>
#     <td class="tg-0lax">0.01</td>
#     <td class="tg-0lax">6</td>
#     <td class="tg-0lax">1.0</td>
#     <td class="tg-0lax">0.0</td>
#     <td class="tg-0lax">0.850</td>
#     <td class="tg-0lax">0.872</td>
#     <td class="tg-0lax">0.847</td>
#     <td class="tg-0lax">0.849</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax"></td>
#     <td class="tg-0lax">0.01</td>
#     <td class="tg-0lax">12</td>
#     <td class="tg-0lax">0.0</td>
#     <td class="tg-0lax">1.0</td>
#     <td class="tg-0lax">0.841</td>
#     <td class="tg-0lax">0.844</td>
#     <td class="tg-0lax">0.849</td>
#     <td class="tg-0lax">0.867</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax"></td>
#     <td class="tg-0lax">0.01</td>
#     <td class="tg-0lax">12</td>
#     <td class="tg-0lax">0.5</td>
#     <td class="tg-0lax">0.5</td>
#     <td class="tg-0lax">0.840</td>
#     <td class="tg-0lax">0.860</td>
#     <td class="tg-0lax">0.861</td>
#     <td class="tg-0lax">0.874</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax"></td>
#     <td class="tg-0lax">0.01</td>
#     <td class="tg-0lax">12</td>
#     <td class="tg-0lax">1.0</td>
#     <td class="tg-0lax">0.0</td>
#     <td class="tg-0lax">0.838</td>
#     <td class="tg-0lax">0.880</td>
#     <td class="tg-0lax">0.874</td>
#     <td class="tg-0lax">0.881</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax"></td>
#     <td class="tg-0lax">0.01</td>
#     <td class="tg-0lax">18</td>
#     <td class="tg-0lax">0.0</td>
#     <td class="tg-0lax">1.0</td>
#     <td class="tg-0lax">0.839</td>
#     <td class="tg-0lax">0.844</td>
#     <td class="tg-0lax">0.849</td>
#     <td class="tg-0lax">0.867</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax"></td>
#     <td class="tg-0lax">0.01</td>
#     <td class="tg-0lax">18</td>
#     <td class="tg-0lax">0.5</td>
#     <td class="tg-0lax">0.5</td>
#     <td class="tg-0lax">0.938</td>
#     <td class="tg-0lax">0.860</td>
#     <td class="tg-0lax">0.862</td>
#     <td class="tg-0lax">0.874</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax"></td>
#     <td class="tg-0lax">0.01</td>
#     <td class="tg-0lax">18</td>
#     <td class="tg-0lax">1.0</td>
#     <td class="tg-0lax">0.0</td>
#     <td class="tg-0lax">0.835</td>
#     <td class="tg-0lax">0.879</td>
#     <td class="tg-0lax">0.874</td>
#     <td class="tg-0lax">0.881</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax"></td>
#     <td class="tg-0lax">0.1</td>
#     <td class="tg-0lax">6</td>
#     <td class="tg-0lax">0.0</td>
#     <td class="tg-0lax">1.0</td>
#     <td class="tg-0lax">0.851</td>
#     <td class="tg-0lax">0.892</td>
#     <td class="tg-0lax">0.908</td>
#     <td class="tg-0lax">0.905</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax"></td>
#     <td class="tg-0lax">0.1</td>
#     <td class="tg-0lax">6</td>
#     <td class="tg-0lax">0.5</td>
#     <td class="tg-0lax">0.5</td>
#     <td class="tg-0lax">0.850</td>
#     <td class="tg-0lax">0.911</td>
#     <td class="tg-0lax">0.920</td>
#     <td class="tg-0lax">0.916</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax"></td>
#     <td class="tg-0lax">0.1</td>
#     <td class="tg-0lax">6</td>
#     <td class="tg-0lax">1.0</td>
#     <td class="tg-0lax">0.0</td>
#     <td class="tg-0lax">0.852</td>
#     <td class="tg-0lax">0.922</td>
#     <td class="tg-0lax">0.925</td>
#     <td class="tg-0lax">0.922</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax"></td>
#     <td class="tg-0lax">0.1</td>
#     <td class="tg-0lax">12</td>
#     <td class="tg-0lax">0.0</td>
#     <td class="tg-0lax">1.0</td>
#     <td class="tg-0lax">0.843</td>
#     <td class="tg-0lax">0.900</td>
#     <td class="tg-0lax">0.913</td>
#     <td class="tg-0lax">0.908</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax"></td>
#     <td class="tg-0lax">0.1</td>
#     <td class="tg-0lax">12</td>
#     <td class="tg-0lax">0.5</td>
#     <td class="tg-0lax">0.5</td>
#     <td class="tg-0lax">0.845</td>
#     <td class="tg-0lax">0.916</td>
#     <td class="tg-0lax">0.923</td>
#     <td class="tg-0lax">0.919</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax"></td>
#     <td class="tg-0lax">0.1</td>
#     <td class="tg-0lax">12</td>
#     <td class="tg-0lax">1.0</td>
#     <td class="tg-0lax">0.0</td>
#     <td class="tg-0lax">0.842</td>
#     <td class="tg-0lax">0.929</td>
#     <td class="tg-0lax">0.931</td>
#     <td class="tg-0lax">0.929</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax"></td>
#     <td class="tg-0lax">0.1</td>
#     <td class="tg-0lax">18</td>
#     <td class="tg-0lax">0.0</td>
#     <td class="tg-0lax">1.0</td>
#     <td class="tg-0lax">0.845</td>
#     <td class="tg-0lax">0.900</td>
#     <td class="tg-0lax">0.913</td>
#     <td class="tg-0lax">0.908</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax"></td>
#     <td class="tg-0lax">0.1</td>
#     <td class="tg-0lax">18</td>
#     <td class="tg-0lax">0.5</td>
#     <td class="tg-0lax">0.5</td>
#     <td class="tg-0lax">0.845</td>
#     <td class="tg-0lax">0.916</td>
#     <td class="tg-0lax">0.923</td>
#     <td class="tg-0lax">0.919</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax"></td>
#     <td class="tg-0lax">0.1</td>
#     <td class="tg-0lax">18</td>
#     <td class="tg-0lax">1.0</td>
#     <td class="tg-0lax">0.0</td>
#     <td class="tg-0lax">0.843</td>
#     <td class="tg-0lax">0.928</td>
#     <td class="tg-0lax">0.931</td>
#     <td class="tg-0lax">0.930</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax"></td>
#     <td class="tg-0lax">0.3</td>
#     <td class="tg-0lax">6</td>
#     <td class="tg-0lax">0.0</td>
#     <td class="tg-0lax">1.0</td>
#     <td class="tg-0lax">0.840</td>
#     <td class="tg-0lax">0.900</td>
#     <td class="tg-0lax">0.908</td>
#     <td class="tg-0lax">0.907</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax"></td>
#     <td class="tg-0lax">0.3</td>
#     <td class="tg-0lax">6</td>
#     <td class="tg-0lax">0.5</td>
#     <td class="tg-0lax">0.5</td>
#     <td class="tg-0lax">0.836</td>
#     <td class="tg-0lax">0.919</td>
#     <td class="tg-0lax">0.929</td>
#     <td class="tg-0lax">0.924</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax"></td>
#     <td class="tg-0lax">0.3</td>
#     <td class="tg-0lax">6</td>
#     <td class="tg-0lax">1.0</td>
#     <td class="tg-0lax">0.0</td>
#     <td class="tg-0lax">0.837</td>
#     <td class="tg-0lax">0.934</td>
#     <td class="tg-0lax">0.938</td>
#     <td class="tg-0lax">0.935</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax"></td>
#     <td class="tg-0lax">0.3</td>
#     <td class="tg-0lax">12</td>
#     <td class="tg-0lax">0.0</td>
#     <td class="tg-0lax">1.0</td>
#     <td class="tg-0lax">0.838</td>
#     <td class="tg-0lax">0.900</td>
#     <td class="tg-0lax">0.912</td>
#     <td class="tg-0lax">0.909</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax"></td>
#     <td class="tg-0lax">0.3</td>
#     <td class="tg-0lax">12</td>
#     <td class="tg-0lax">0.5</td>
#     <td class="tg-0lax">0.5</td>
#     <td class="tg-0lax">0.839</td>
#     <td class="tg-0lax">0.920</td>
#     <td class="tg-0lax">0.929</td>
#     <td class="tg-0lax">0.925</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax"></td>
#     <td class="tg-0lax">0.3</td>
#     <td class="tg-0lax">12</td>
#     <td class="tg-0lax">1.0</td>
#     <td class="tg-0lax">0.0</td>
#     <td class="tg-0lax">0.839</td>
#     <td class="tg-0lax">0.936</td>
#     <td class="tg-0lax">0.939</td>
#     <td class="tg-0lax">0.936</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax"></td>
#     <td class="tg-0lax">0.3</td>
#     <td class="tg-0lax">18</td>
#     <td class="tg-0lax">0.0</td>
#     <td class="tg-0lax">1.0</td>
#     <td class="tg-0lax">0.841</td>
#     <td class="tg-0lax">0.900</td>
#     <td class="tg-0lax">0.912</td>
#     <td class="tg-0lax">0.910</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax"></td>
#     <td class="tg-0lax">0.3</td>
#     <td class="tg-0lax">18</td>
#     <td class="tg-0lax">0.5</td>
#     <td class="tg-0lax">0.5</td>
#     <td class="tg-0lax">0.840</td>
#     <td class="tg-0lax">0.920</td>
#     <td class="tg-0lax">0.929</td>
#     <td class="tg-0lax">0.926</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax"></td>
#     <td class="tg-0lax">0.3</td>
#     <td class="tg-0lax">18</td>
#     <td class="tg-0lax">1.0</td>
#     <td class="tg-0lax">0.0</td>
#     <td class="tg-0lax">0.840</td>
#     <td class="tg-0lax">0.936</td>
#     <td class="tg-0lax">0.939</td>
#     <td class="tg-0lax">0.936</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax"></td>
#     <td class="tg-0lax">1.0</td>
#     <td class="tg-0lax">6</td>
#     <td class="tg-0lax">0.0</td>
#     <td class="tg-0lax">1.0</td>
#     <td class="tg-0lax">0.821</td>
#     <td class="tg-0lax">0.900</td>
#     <td class="tg-0lax">0.909</td>
#     <td class="tg-0lax">0.911</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax"></td>
#     <td class="tg-0lax">1.0</td>
#     <td class="tg-0lax">6</td>
#     <td class="tg-0lax">0.5</td>
#     <td class="tg-0lax">0.5</td>
#     <td class="tg-0lax">0.819</td>
#     <td class="tg-0lax">0.922</td>
#     <td class="tg-0lax">0.931</td>
#     <td class="tg-0lax">0.927</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax"></td>
#     <td class="tg-0lax">1.0</td>
#     <td class="tg-0lax">6</td>
#     <td class="tg-0lax">1.0</td>
#     <td class="tg-0lax">0.0</td>
#     <td class="tg-0lax">0.815</td>
#     <td class="tg-0lax">0.937</td>
#     <td class="tg-0lax">0.940</td>
#     <td class="tg-0lax">0.936</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax"></td>
#     <td class="tg-0lax">1.0</td>
#     <td class="tg-0lax">12</td>
#     <td class="tg-0lax">0.0</td>
#     <td class="tg-0lax">1.0</td>
#     <td class="tg-0lax">0.827</td>
#     <td class="tg-0lax">0.892</td>
#     <td class="tg-0lax">0.915</td>
#     <td class="tg-0lax">0.911</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax"></td>
#     <td class="tg-0lax">1.0</td>
#     <td class="tg-0lax">12</td>
#     <td class="tg-0lax">0.5</td>
#     <td class="tg-0lax">0.5</td>
#     <td class="tg-0lax">0.829</td>
#     <td class="tg-0lax">0.924</td>
#     <td class="tg-0lax">0.934</td>
#     <td class="tg-0lax">0.926</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax"></td>
#     <td class="tg-0lax">1.0</td>
#     <td class="tg-0lax">12</td>
#     <td class="tg-0lax">1.0</td>
#     <td class="tg-0lax">0.0</td>
#     <td class="tg-0lax">0.830</td>
#     <td class="tg-0lax">0.937</td>
#     <td class="tg-0lax">0.938</td>
#     <td class="tg-0lax">0.936</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax"></td>
#     <td class="tg-0lax">1.0</td>
#     <td class="tg-0lax">18</td>
#     <td class="tg-0lax">0.0</td>
#     <td class="tg-0lax">1.0</td>
#     <td class="tg-0lax">0.828</td>
#     <td class="tg-0lax">0.892</td>
#     <td class="tg-0lax">0.914</td>
#     <td class="tg-0lax">0.911</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax"></td>
#     <td class="tg-0lax">1.0</td>
#     <td class="tg-0lax">18</td>
#     <td class="tg-0lax">0.5</td>
#     <td class="tg-0lax">0.5</td>
#     <td class="tg-0lax">0.830</td>
#     <td class="tg-0lax">0.924</td>
#     <td class="tg-0lax">0.934</td>
#     <td class="tg-0lax">0.926</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax"></td>
#     <td class="tg-0lax">1.0</td>
#     <td class="tg-0lax">18</td>
#     <td class="tg-0lax">1.0</td>
#     <td class="tg-0lax">0.0</td>
#     <td class="tg-0lax">0.830</td>
#     <td class="tg-0lax">0.937</td>
#     <td class="tg-0lax">0.938</td>
#     <td class="tg-0lax">0.937</td>
#   </tr>
# </tbody>
# </table>
#
# ### Without Weather Data:
# <style type="text/css">
# .tg  {border-collapse:collapse;border-spacing:0;}
# .tg td{border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;
#   overflow:hidden;padding:10px 5px;word-break:normal;}
# .tg th{border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;
#   font-weight:normal;overflow:hidden;padding:10px 5px;word-break:normal;}
# .tg .tg-0lax{text-align:left;vertical-align:top}
# </style>
# <table class="tg">
# <thead>
#   <tr>
#     <th class="tg-0lax">Logit</th>
#     <th class="tg-0lax">max_iter</th>
#     <th class="tg-0lax">Availability</th>
#     <th class="tg-0lax">Usage_TD</th>
#     <th class="tg-0lax">Usage_WM</th>
#     <th class="tg-0lax">Usage_DW</th>
#   </tr>
# </thead>
# <tbody>
#   <tr>
#     <td class="tg-0lax"></td>
#     <td class="tg-0lax">10</td>
#     <td class="tg-0lax">0.835</td>
#     <td class="tg-0lax">0.702</td>
#     <td class="tg-0lax">0.689</td>
#     <td class="tg-0lax">0.676</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax"></td>
#     <td class="tg-0lax">100</td>
#     <td class="tg-0lax">0.838</td>
#     <td class="tg-0lax">0.702</td>
#     <td class="tg-0lax">0.689</td>
#     <td class="tg-0lax">0.676</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax"></td>
#     <td class="tg-0lax">1000</td>
#     <td class="tg-0lax">0.838</td>
#     <td class="tg-0lax">0.702</td>
#     <td class="tg-0lax">0.689</td>
#     <td class="tg-0lax">0.676</td>
#   </tr>
# </tbody>
# </table>
#
# <style type="text/css">
# .tg  {border-collapse:collapse;border-spacing:0;}
# .tg td{border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;
#   overflow:hidden;padding:10px 5px;word-break:normal;}
# .tg th{border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;
#   font-weight:normal;overflow:hidden;padding:10px 5px;word-break:normal;}
# .tg .tg-0lax{text-align:left;vertical-align:top}
# </style>
# <table class="tg">
# <thead>
#   <tr>
#     <th class="tg-0lax">Random Forest</th>
#     <th class="tg-0lax">max_depth</th>
#     <th class="tg-0lax">n_estimators</th>
#     <th class="tg-0lax">max_features</th>
#     <th class="tg-0lax">Availability</th>
#     <th class="tg-0lax">Usage_TD</th>
#     <th class="tg-0lax">Usage_WM</th>
#     <th class="tg-0lax">Usage_DW</th>
#   </tr>
# </thead>
# <tbody>
#   <tr>
#     <td class="tg-0lax"></td>
#     <td class="tg-0lax">5</td>
#     <td class="tg-0lax">100</td>
#     <td class="tg-0lax">auto</td>
#     <td class="tg-0lax">0.845</td>
#     <td class="tg-0lax">0.709</td>
#     <td class="tg-0lax">0.677</td>
#     <td class="tg-0lax">0.713</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax"></td>
#     <td class="tg-0lax">5</td>
#     <td class="tg-0lax">100</td>
#     <td class="tg-0lax">sqrt</td>
#     <td class="tg-0lax">0.845</td>
#     <td class="tg-0lax">0.712</td>
#     <td class="tg-0lax">0.678</td>
#     <td class="tg-0lax">0.711</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax"></td>
#     <td class="tg-0lax">5</td>
#     <td class="tg-0lax">100</td>
#     <td class="tg-0lax">log2</td>
#     <td class="tg-0lax">0.845</td>
#     <td class="tg-0lax">0.713</td>
#     <td class="tg-0lax">0.679</td>
#     <td class="tg-0lax">0.714</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax"></td>
#     <td class="tg-0lax">5</td>
#     <td class="tg-0lax">500</td>
#     <td class="tg-0lax">auto</td>
#     <td class="tg-0lax">0.845</td>
#     <td class="tg-0lax">0.713</td>
#     <td class="tg-0lax">0.681</td>
#     <td class="tg-0lax">0.711</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax"></td>
#     <td class="tg-0lax">5</td>
#     <td class="tg-0lax">500</td>
#     <td class="tg-0lax">sqrt</td>
#     <td class="tg-0lax">0.845</td>
#     <td class="tg-0lax">0.713</td>
#     <td class="tg-0lax">0.682</td>
#     <td class="tg-0lax">0.714</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax"></td>
#     <td class="tg-0lax">5</td>
#     <td class="tg-0lax">500</td>
#     <td class="tg-0lax">log2</td>
#     <td class="tg-0lax">0.845</td>
#     <td class="tg-0lax">0.713</td>
#     <td class="tg-0lax">0.680</td>
#     <td class="tg-0lax">0.713</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax"></td>
#     <td class="tg-0lax">5</td>
#     <td class="tg-0lax">1000</td>
#     <td class="tg-0lax">auto</td>
#     <td class="tg-0lax">0.845</td>
#     <td class="tg-0lax">0.713</td>
#     <td class="tg-0lax">0.681</td>
#     <td class="tg-0lax">0.715</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax"></td>
#     <td class="tg-0lax">5</td>
#     <td class="tg-0lax">1000</td>
#     <td class="tg-0lax">sqrt</td>
#     <td class="tg-0lax">0.845</td>
#     <td class="tg-0lax">0.714</td>
#     <td class="tg-0lax">0.681</td>
#     <td class="tg-0lax">0.712</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax"></td>
#     <td class="tg-0lax">5</td>
#     <td class="tg-0lax">1000</td>
#     <td class="tg-0lax">log2</td>
#     <td class="tg-0lax">0.845</td>
#     <td class="tg-0lax">0.713</td>
#     <td class="tg-0lax">0.682</td>
#     <td class="tg-0lax">0.712</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax"></td>
#     <td class="tg-0lax">10</td>
#     <td class="tg-0lax">100</td>
#     <td class="tg-0lax">auto</td>
#     <td class="tg-0lax">0.834</td>
#     <td class="tg-0lax">0.711</td>
#     <td class="tg-0lax">0.684</td>
#     <td class="tg-0lax">0.710</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax"></td>
#     <td class="tg-0lax">10</td>
#     <td class="tg-0lax">100</td>
#     <td class="tg-0lax">sqrt</td>
#     <td class="tg-0lax">0.835</td>
#     <td class="tg-0lax">0.714</td>
#     <td class="tg-0lax">0.680</td>
#     <td class="tg-0lax">0.711</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax"></td>
#     <td class="tg-0lax">10</td>
#     <td class="tg-0lax">100</td>
#     <td class="tg-0lax">log2</td>
#     <td class="tg-0lax">0.835</td>
#     <td class="tg-0lax">0.712</td>
#     <td class="tg-0lax">0.677</td>
#     <td class="tg-0lax">0.710</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax"></td>
#     <td class="tg-0lax">10</td>
#     <td class="tg-0lax">500</td>
#     <td class="tg-0lax">auto</td>
#     <td class="tg-0lax">0.835</td>
#     <td class="tg-0lax">0.712</td>
#     <td class="tg-0lax">0.682</td>
#     <td class="tg-0lax">0.714</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax"></td>
#     <td class="tg-0lax">10</td>
#     <td class="tg-0lax">500</td>
#     <td class="tg-0lax">sqrt</td>
#     <td class="tg-0lax">0.835</td>
#     <td class="tg-0lax">0.713</td>
#     <td class="tg-0lax">0.683</td>
#     <td class="tg-0lax">0.714</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax"></td>
#     <td class="tg-0lax">10</td>
#     <td class="tg-0lax">500</td>
#     <td class="tg-0lax">log2</td>
#     <td class="tg-0lax">0.835</td>
#     <td class="tg-0lax">0.713</td>
#     <td class="tg-0lax">0.682</td>
#     <td class="tg-0lax">0.713</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax"></td>
#     <td class="tg-0lax">10</td>
#     <td class="tg-0lax">1000</td>
#     <td class="tg-0lax">auto</td>
#     <td class="tg-0lax">0.835</td>
#     <td class="tg-0lax">0.713</td>
#     <td class="tg-0lax">0.682</td>
#     <td class="tg-0lax">0.713</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax"></td>
#     <td class="tg-0lax">10</td>
#     <td class="tg-0lax">1000</td>
#     <td class="tg-0lax">sqrt</td>
#     <td class="tg-0lax">0.835</td>
#     <td class="tg-0lax">0.713</td>
#     <td class="tg-0lax">0.682</td>
#     <td class="tg-0lax">0.715</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax"></td>
#     <td class="tg-0lax">10</td>
#     <td class="tg-0lax">1000</td>
#     <td class="tg-0lax">log2</td>
#     <td class="tg-0lax">0.835</td>
#     <td class="tg-0lax">0.713</td>
#     <td class="tg-0lax">0.683</td>
#     <td class="tg-0lax">0.715</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax"></td>
#     <td class="tg-0lax">20</td>
#     <td class="tg-0lax">100</td>
#     <td class="tg-0lax">auto</td>
#     <td class="tg-0lax">0.814</td>
#     <td class="tg-0lax">0.715</td>
#     <td class="tg-0lax">0.682</td>
#     <td class="tg-0lax">0.710</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax"></td>
#     <td class="tg-0lax">20</td>
#     <td class="tg-0lax">100</td>
#     <td class="tg-0lax">sqrt</td>
#     <td class="tg-0lax">0.813</td>
#     <td class="tg-0lax">0.711</td>
#     <td class="tg-0lax">0.678</td>
#     <td class="tg-0lax">0.714</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax"></td>
#     <td class="tg-0lax">20</td>
#     <td class="tg-0lax">100</td>
#     <td class="tg-0lax">log2</td>
#     <td class="tg-0lax">0.813</td>
#     <td class="tg-0lax">0.719</td>
#     <td class="tg-0lax">0.680</td>
#     <td class="tg-0lax">0.716</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax"></td>
#     <td class="tg-0lax">20</td>
#     <td class="tg-0lax">500</td>
#     <td class="tg-0lax">auto</td>
#     <td class="tg-0lax">0.814</td>
#     <td class="tg-0lax">0.713</td>
#     <td class="tg-0lax">0.683</td>
#     <td class="tg-0lax">0.712</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax"></td>
#     <td class="tg-0lax">20</td>
#     <td class="tg-0lax">500</td>
#     <td class="tg-0lax">sqrt</td>
#     <td class="tg-0lax">0.814</td>
#     <td class="tg-0lax">0.712</td>
#     <td class="tg-0lax">0.682</td>
#     <td class="tg-0lax">0.715</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax"></td>
#     <td class="tg-0lax">20</td>
#     <td class="tg-0lax">500</td>
#     <td class="tg-0lax">log2</td>
#     <td class="tg-0lax">0.814</td>
#     <td class="tg-0lax">0.712</td>
#     <td class="tg-0lax">0.682</td>
#     <td class="tg-0lax">0.711</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax"></td>
#     <td class="tg-0lax">20</td>
#     <td class="tg-0lax">1000</td>
#     <td class="tg-0lax">auto</td>
#     <td class="tg-0lax">0.814</td>
#     <td class="tg-0lax">0.713</td>
#     <td class="tg-0lax">0.682</td>
#     <td class="tg-0lax">0.713</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax"></td>
#     <td class="tg-0lax">20</td>
#     <td class="tg-0lax">1000</td>
#     <td class="tg-0lax">sqrt</td>
#     <td class="tg-0lax">0.814</td>
#     <td class="tg-0lax">0.713</td>
#     <td class="tg-0lax">0.681</td>
#     <td class="tg-0lax">0.713</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax"></td>
#     <td class="tg-0lax">20</td>
#     <td class="tg-0lax">1000</td>
#     <td class="tg-0lax">log2</td>
#     <td class="tg-0lax">0.814</td>
#     <td class="tg-0lax">0.713</td>
#     <td class="tg-0lax">0.682</td>
#     <td class="tg-0lax">0.713</td>
#   </tr>
# </tbody>
# </table>
#
# <style type="text/css">
# .tg  {border-collapse:collapse;border-spacing:0;}
# .tg td{border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;
#   overflow:hidden;padding:10px 5px;word-break:normal;}
# .tg th{border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;
#   font-weight:normal;overflow:hidden;padding:10px 5px;word-break:normal;}
# .tg .tg-0lax{text-align:left;vertical-align:top}
# </style>
# <table class="tg">
# <thead>
#   <tr>
#     <th class="tg-0lax">Adaboost</th>
#     <th class="tg-0lax">learning_rate</th>
#     <th class="tg-0lax">n_estimators</th>
#     <th class="tg-0lax">Availability</th>
#     <th class="tg-0lax">Usage_TD</th>
#     <th class="tg-0lax">Usage_WM</th>
#     <th class="tg-0lax">Usage_DW</th>
#   </tr>
# </thead>
# <tbody>
#   <tr>
#     <td class="tg-0lax"></td>
#     <td class="tg-0lax">0.001</td>
#     <td class="tg-0lax">50</td>
#     <td class="tg-0lax">0.756</td>
#     <td class="tg-0lax">0.690</td>
#     <td class="tg-0lax">0.643</td>
#     <td class="tg-0lax">0.678</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax"></td>
#     <td class="tg-0lax">0.001</td>
#     <td class="tg-0lax">100</td>
#     <td class="tg-0lax">0.756</td>
#     <td class="tg-0lax">0.702</td>
#     <td class="tg-0lax">0.643</td>
#     <td class="tg-0lax">0.687</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax"></td>
#     <td class="tg-0lax">0.001</td>
#     <td class="tg-0lax">500</td>
#     <td class="tg-0lax">0.817</td>
#     <td class="tg-0lax">0.704</td>
#     <td class="tg-0lax">0.697</td>
#     <td class="tg-0lax">0.699</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax"></td>
#     <td class="tg-0lax">0.01</td>
#     <td class="tg-0lax">50</td>
#     <td class="tg-0lax">0.817</td>
#     <td class="tg-0lax">0.705</td>
#     <td class="tg-0lax">0.696</td>
#     <td class="tg-0lax">0.699</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax"></td>
#     <td class="tg-0lax">0.01</td>
#     <td class="tg-0lax">100</td>
#     <td class="tg-0lax">0.833</td>
#     <td class="tg-0lax">0.711</td>
#     <td class="tg-0lax">0.701</td>
#     <td class="tg-0lax">0.701</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax"></td>
#     <td class="tg-0lax">0.01</td>
#     <td class="tg-0lax">500</td>
#     <td class="tg-0lax">0.843</td>
#     <td class="tg-0lax">0.710</td>
#     <td class="tg-0lax">0.699</td>
#     <td class="tg-0lax">0.681</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax"></td>
#     <td class="tg-0lax">0.1</td>
#     <td class="tg-0lax">50</td>
#     <td class="tg-0lax">0.843</td>
#     <td class="tg-0lax">0.710</td>
#     <td class="tg-0lax">0.698</td>
#     <td class="tg-0lax">0.681</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax"></td>
#     <td class="tg-0lax">0.1</td>
#     <td class="tg-0lax">100</td>
#     <td class="tg-0lax">0.846</td>
#     <td class="tg-0lax">0.710</td>
#     <td class="tg-0lax">0.702</td>
#     <td class="tg-0lax">0.680</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax"></td>
#     <td class="tg-0lax">0.1</td>
#     <td class="tg-0lax">500</td>
#     <td class="tg-0lax">0.848</td>
#     <td class="tg-0lax">0.710</td>
#     <td class="tg-0lax">0.701</td>
#     <td class="tg-0lax">0.680</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax"></td>
#     <td class="tg-0lax">1.0</td>
#     <td class="tg-0lax">50</td>
#     <td class="tg-0lax">0.848</td>
#     <td class="tg-0lax">0.710</td>
#     <td class="tg-0lax">0.701</td>
#     <td class="tg-0lax">0.680</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax"></td>
#     <td class="tg-0lax">1.0</td>
#     <td class="tg-0lax">100</td>
#     <td class="tg-0lax">0.848</td>
#     <td class="tg-0lax">0.710</td>
#     <td class="tg-0lax">0.701</td>
#     <td class="tg-0lax">0.680</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax"></td>
#     <td class="tg-0lax">1.0</td>
#     <td class="tg-0lax">500</td>
#     <td class="tg-0lax">0.849</td>
#     <td class="tg-0lax">0.710</td>
#     <td class="tg-0lax">0.701</td>
#     <td class="tg-0lax">0.680</td>
#   </tr>
# </tbody>
# </table>
#
# <style type="text/css">
# .tg  {border-collapse:collapse;border-spacing:0;}
# .tg td{border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;
#   overflow:hidden;padding:10px 5px;word-break:normal;}
# .tg th{border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;
#   font-weight:normal;overflow:hidden;padding:10px 5px;word-break:normal;}
# .tg .tg-0lax{text-align:left;vertical-align:top}
# </style>
# <table class="tg">
# <thead>
#   <tr>
#     <th class="tg-0lax">KNN</th>
#     <th class="tg-0lax">n_neighbors</th>
#     <th class="tg-0lax">leaf_size</th>
#     <th class="tg-0lax">Availability</th>
#     <th class="tg-0lax">Usage_TD</th>
#     <th class="tg-0lax">Usage_WM</th>
#     <th class="tg-0lax">Usage_DW</th>
#   </tr>
# </thead>
# <tbody>
#   <tr>
#     <td class="tg-0lax"></td>
#     <td class="tg-0lax">30</td>
#     <td class="tg-0lax">1</td>
#     <td class="tg-0lax">0.701</td>
#     <td class="tg-0lax">0.705</td>
#     <td class="tg-0lax">0.831</td>
#     <td class="tg-0lax">0.879</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax"></td>
#     <td class="tg-0lax">30</td>
#     <td class="tg-0lax">5</td>
#     <td class="tg-0lax">0.806</td>
#     <td class="tg-0lax">0.766</td>
#     <td class="tg-0lax">0.752</td>
#     <td class="tg-0lax">0.800</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax"></td>
#     <td class="tg-0lax">30</td>
#     <td class="tg-0lax">10</td>
#     <td class="tg-0lax">0.826</td>
#     <td class="tg-0lax">0.738</td>
#     <td class="tg-0lax">0.718</td>
#     <td class="tg-0lax">0.779</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax"></td>
#     <td class="tg-0lax">60</td>
#     <td class="tg-0lax">1</td>
#     <td class="tg-0lax">0.7</td>
#     <td class="tg-0lax">0.811</td>
#     <td class="tg-0lax">0.756</td>
#     <td class="tg-0lax">0.767</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax"></td>
#     <td class="tg-0lax">60</td>
#     <td class="tg-0lax">5</td>
#     <td class="tg-0lax">0.807</td>
#     <td class="tg-0lax">0.786</td>
#     <td class="tg-0lax">0.741</td>
#     <td class="tg-0lax">0.772</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax"></td>
#     <td class="tg-0lax">60</td>
#     <td class="tg-0lax">10</td>
#     <td class="tg-0lax">0.825</td>
#     <td class="tg-0lax">0.737</td>
#     <td class="tg-0lax">0.731</td>
#     <td class="tg-0lax">0.761</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax"></td>
#     <td class="tg-0lax">90</td>
#     <td class="tg-0lax">1</td>
#     <td class="tg-0lax">0.698</td>
#     <td class="tg-0lax">0.830</td>
#     <td class="tg-0lax">0.794</td>
#     <td class="tg-0lax">0.782</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax"></td>
#     <td class="tg-0lax">90</td>
#     <td class="tg-0lax">5</td>
#     <td class="tg-0lax">0.807</td>
#     <td class="tg-0lax">0.784</td>
#     <td class="tg-0lax">0.735</td>
#     <td class="tg-0lax">0.760</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax"></td>
#     <td class="tg-0lax">90</td>
#     <td class="tg-0lax">10</td>
#     <td class="tg-0lax">0.825</td>
#     <td class="tg-0lax">0.728</td>
#     <td class="tg-0lax">0.728</td>
#     <td class="tg-0lax">0.745</td>
#   </tr>
# </tbody>
# </table>
#
# <style type="text/css">
# .tg  {border-collapse:collapse;border-spacing:0;}
# .tg td{border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;
#   overflow:hidden;padding:10px 5px;word-break:normal;}
# .tg th{border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;
#   font-weight:normal;overflow:hidden;padding:10px 5px;word-break:normal;}
# .tg .tg-0lax{text-align:left;vertical-align:top}
# </style>
# <table class="tg">
# <thead>
#   <tr>
#     <th class="tg-0lax">XGBoost</th>
#     <th class="tg-0lax">learning_rate</th>
#     <th class="tg-0lax">max_depth</th>
#     <th class="tg-0lax">lambda</th>
#     <th class="tg-0lax">alpha</th>
#     <th class="tg-0lax">Availability</th>
#     <th class="tg-0lax">Usage_TD</th>
#     <th class="tg-0lax">Usage_WM</th>
#     <th class="tg-0lax">Usage_DW</th>
#   </tr>
# </thead>
# <tbody>
#   <tr>
#     <td class="tg-0lax"></td>
#     <td class="tg-0lax">0.01</td>
#     <td class="tg-0lax">6</td>
#     <td class="tg-0lax">0.0</td>
#     <td class="tg-0lax">1.0</td>
#     <td class="tg-0lax">0.846</td>
#     <td class="tg-0lax">0.707</td>
#     <td class="tg-0lax">0.686</td>
#     <td class="tg-0lax">0.703</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax"></td>
#     <td class="tg-0lax">0.01</td>
#     <td class="tg-0lax">6</td>
#     <td class="tg-0lax">0.5</td>
#     <td class="tg-0lax">0.5</td>
#     <td class="tg-0lax">0.846</td>
#     <td class="tg-0lax">0.708</td>
#     <td class="tg-0lax">0.685</td>
#     <td class="tg-0lax">0.704</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax"></td>
#     <td class="tg-0lax">0.01</td>
#     <td class="tg-0lax">6</td>
#     <td class="tg-0lax">1.0</td>
#     <td class="tg-0lax">0.0</td>
#     <td class="tg-0lax">0.845</td>
#     <td class="tg-0lax">0.712</td>
#     <td class="tg-0lax">0.682</td>
#     <td class="tg-0lax">0.710</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax"></td>
#     <td class="tg-0lax">0.01</td>
#     <td class="tg-0lax">12</td>
#     <td class="tg-0lax">0.0</td>
#     <td class="tg-0lax">1.0</td>
#     <td class="tg-0lax">0.841</td>
#     <td class="tg-0lax">0.707</td>
#     <td class="tg-0lax">0.686</td>
#     <td class="tg-0lax">0.703</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax"></td>
#     <td class="tg-0lax">0.01</td>
#     <td class="tg-0lax">12</td>
#     <td class="tg-0lax">0.5</td>
#     <td class="tg-0lax">0.5</td>
#     <td class="tg-0lax">0.840</td>
#     <td class="tg-0lax">0.708</td>
#     <td class="tg-0lax">0.685</td>
#     <td class="tg-0lax">0.704</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax"></td>
#     <td class="tg-0lax">0.01</td>
#     <td class="tg-0lax">12</td>
#     <td class="tg-0lax">1.0</td>
#     <td class="tg-0lax">0.0</td>
#     <td class="tg-0lax">0.838</td>
#     <td class="tg-0lax">0.712</td>
#     <td class="tg-0lax">0.682</td>
#     <td class="tg-0lax">0.710</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax"></td>
#     <td class="tg-0lax">0.01</td>
#     <td class="tg-0lax">18</td>
#     <td class="tg-0lax">0.0</td>
#     <td class="tg-0lax">1.0</td>
#     <td class="tg-0lax">0.840</td>
#     <td class="tg-0lax">0.707</td>
#     <td class="tg-0lax">0.686</td>
#     <td class="tg-0lax">0.703</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax"></td>
#     <td class="tg-0lax">0.01</td>
#     <td class="tg-0lax">18</td>
#     <td class="tg-0lax">0.5</td>
#     <td class="tg-0lax">0.5</td>
#     <td class="tg-0lax">0.839</td>
#     <td class="tg-0lax">0.708</td>
#     <td class="tg-0lax">0.685</td>
#     <td class="tg-0lax">0.704</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax"></td>
#     <td class="tg-0lax">0.01</td>
#     <td class="tg-0lax">18</td>
#     <td class="tg-0lax">1.0</td>
#     <td class="tg-0lax">0.0</td>
#     <td class="tg-0lax">0.836</td>
#     <td class="tg-0lax">0.712</td>
#     <td class="tg-0lax">0.682</td>
#     <td class="tg-0lax">0.710</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax"></td>
#     <td class="tg-0lax">0.1</td>
#     <td class="tg-0lax">6</td>
#     <td class="tg-0lax">0.0</td>
#     <td class="tg-0lax">1.0</td>
#     <td class="tg-0lax">0.841</td>
#     <td class="tg-0lax">0.712</td>
#     <td class="tg-0lax">0.686</td>
#     <td class="tg-0lax">0.706</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax"></td>
#     <td class="tg-0lax">0.1</td>
#     <td class="tg-0lax">6</td>
#     <td class="tg-0lax">0.5</td>
#     <td class="tg-0lax">0.5</td>
#     <td class="tg-0lax">0.840</td>
#     <td class="tg-0lax">0.713</td>
#     <td class="tg-0lax">0.683</td>
#     <td class="tg-0lax">0.708</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax"></td>
#     <td class="tg-0lax">0.1</td>
#     <td class="tg-0lax">6</td>
#     <td class="tg-0lax">1.0</td>
#     <td class="tg-0lax">0.0</td>
#     <td class="tg-0lax">0.839</td>
#     <td class="tg-0lax">0.712</td>
#     <td class="tg-0lax">0.681</td>
#     <td class="tg-0lax">0.713</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax"></td>
#     <td class="tg-0lax">0.1</td>
#     <td class="tg-0lax">12</td>
#     <td class="tg-0lax">0.0</td>
#     <td class="tg-0lax">1.0</td>
#     <td class="tg-0lax">0.832</td>
#     <td class="tg-0lax">0.712</td>
#     <td class="tg-0lax">0.686</td>
#     <td class="tg-0lax">0.706</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax"></td>
#     <td class="tg-0lax">0.1</td>
#     <td class="tg-0lax">12</td>
#     <td class="tg-0lax">0.5</td>
#     <td class="tg-0lax">0.5</td>
#     <td class="tg-0lax">0.827</td>
#     <td class="tg-0lax">0.713</td>
#     <td class="tg-0lax">0.683</td>
#     <td class="tg-0lax">0.708</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax"></td>
#     <td class="tg-0lax">0.1</td>
#     <td class="tg-0lax">12</td>
#     <td class="tg-0lax">1.0</td>
#     <td class="tg-0lax">0.0</td>
#     <td class="tg-0lax">0.823</td>
#     <td class="tg-0lax">0.712</td>
#     <td class="tg-0lax">0.681</td>
#     <td class="tg-0lax">0.713</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax"></td>
#     <td class="tg-0lax">0.1</td>
#     <td class="tg-0lax">18</td>
#     <td class="tg-0lax">0.0</td>
#     <td class="tg-0lax">1.0</td>
#     <td class="tg-0lax">0.831</td>
#     <td class="tg-0lax">0.712</td>
#     <td class="tg-0lax">0.686</td>
#     <td class="tg-0lax">0.706</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax"></td>
#     <td class="tg-0lax">0.1</td>
#     <td class="tg-0lax">18</td>
#     <td class="tg-0lax">0.5</td>
#     <td class="tg-0lax">0.5</td>
#     <td class="tg-0lax">0.827</td>
#     <td class="tg-0lax">0.713</td>
#     <td class="tg-0lax">0.683</td>
#     <td class="tg-0lax">0.708</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax"></td>
#     <td class="tg-0lax">0.1</td>
#     <td class="tg-0lax">18</td>
#     <td class="tg-0lax">1.0</td>
#     <td class="tg-0lax">0.0</td>
#     <td class="tg-0lax">0.820</td>
#     <td class="tg-0lax">0.712</td>
#     <td class="tg-0lax">0.681</td>
#     <td class="tg-0lax">0.713</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax"></td>
#     <td class="tg-0lax">0.3</td>
#     <td class="tg-0lax">6</td>
#     <td class="tg-0lax">0.0</td>
#     <td class="tg-0lax">1.0</td>
#     <td class="tg-0lax">0.836</td>
#     <td class="tg-0lax">0.712</td>
#     <td class="tg-0lax">0.686</td>
#     <td class="tg-0lax">0.706</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax"></td>
#     <td class="tg-0lax">0.3</td>
#     <td class="tg-0lax">6</td>
#     <td class="tg-0lax">0.5</td>
#     <td class="tg-0lax">0.5</td>
#     <td class="tg-0lax">0.832</td>
#     <td class="tg-0lax">0.713</td>
#     <td class="tg-0lax">0.683</td>
#     <td class="tg-0lax">0.708</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax"></td>
#     <td class="tg-0lax">0.3</td>
#     <td class="tg-0lax">6</td>
#     <td class="tg-0lax">1.0</td>
#     <td class="tg-0lax">0.0</td>
#     <td class="tg-0lax">0.828</td>
#     <td class="tg-0lax">0.712</td>
#     <td class="tg-0lax">0.681</td>
#     <td class="tg-0lax">0.713</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax"></td>
#     <td class="tg-0lax">0.3</td>
#     <td class="tg-0lax">12</td>
#     <td class="tg-0lax">0.0</td>
#     <td class="tg-0lax">1.0</td>
#     <td class="tg-0lax">0.830</td>
#     <td class="tg-0lax">0.712</td>
#     <td class="tg-0lax">0.686</td>
#     <td class="tg-0lax">0.706</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax"></td>
#     <td class="tg-0lax">0.3</td>
#     <td class="tg-0lax">12</td>
#     <td class="tg-0lax">0.5</td>
#     <td class="tg-0lax">0.5</td>
#     <td class="tg-0lax">0.821</td>
#     <td class="tg-0lax">0.713</td>
#     <td class="tg-0lax">0.683</td>
#     <td class="tg-0lax">0.708</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax"></td>
#     <td class="tg-0lax">0.3</td>
#     <td class="tg-0lax">12</td>
#     <td class="tg-0lax">1.0</td>
#     <td class="tg-0lax">0.0</td>
#     <td class="tg-0lax">0.812</td>
#     <td class="tg-0lax">0.712</td>
#     <td class="tg-0lax">0.681</td>
#     <td class="tg-0lax">0.713</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax"></td>
#     <td class="tg-0lax">0.3</td>
#     <td class="tg-0lax">18</td>
#     <td class="tg-0lax">0.0</td>
#     <td class="tg-0lax">1.0</td>
#     <td class="tg-0lax">0.829</td>
#     <td class="tg-0lax">0.712</td>
#     <td class="tg-0lax">0.686</td>
#     <td class="tg-0lax">0.706</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax"></td>
#     <td class="tg-0lax">0.3</td>
#     <td class="tg-0lax">18</td>
#     <td class="tg-0lax">0.5</td>
#     <td class="tg-0lax">0.5</td>
#     <td class="tg-0lax">0.821</td>
#     <td class="tg-0lax">0.713</td>
#     <td class="tg-0lax">0.683</td>
#     <td class="tg-0lax">0.708</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax"></td>
#     <td class="tg-0lax">0.3</td>
#     <td class="tg-0lax">18</td>
#     <td class="tg-0lax">1.0</td>
#     <td class="tg-0lax">0.0</td>
#     <td class="tg-0lax">0.809</td>
#     <td class="tg-0lax">0.712</td>
#     <td class="tg-0lax">0.681</td>
#     <td class="tg-0lax">0.713</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax"></td>
#     <td class="tg-0lax">1.0</td>
#     <td class="tg-0lax">6</td>
#     <td class="tg-0lax">0.0</td>
#     <td class="tg-0lax">1.0</td>
#     <td class="tg-0lax">0.830</td>
#     <td class="tg-0lax">0.711</td>
#     <td class="tg-0lax">0.687</td>
#     <td class="tg-0lax">0.705</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax"></td>
#     <td class="tg-0lax">1.0</td>
#     <td class="tg-0lax">6</td>
#     <td class="tg-0lax">0.5</td>
#     <td class="tg-0lax">0.5</td>
#     <td class="tg-0lax">0.823</td>
#     <td class="tg-0lax">0.712</td>
#     <td class="tg-0lax">0.684</td>
#     <td class="tg-0lax">0.708</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax"></td>
#     <td class="tg-0lax">1.0</td>
#     <td class="tg-0lax">6</td>
#     <td class="tg-0lax">1.0</td>
#     <td class="tg-0lax">0.0</td>
#     <td class="tg-0lax">0.815</td>
#     <td class="tg-0lax">0.712</td>
#     <td class="tg-0lax">0.681</td>
#     <td class="tg-0lax">0.713</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax"></td>
#     <td class="tg-0lax">1.0</td>
#     <td class="tg-0lax">12</td>
#     <td class="tg-0lax">0.0</td>
#     <td class="tg-0lax">1.0</td>
#     <td class="tg-0lax">0.824</td>
#     <td class="tg-0lax">0.711</td>
#     <td class="tg-0lax">0.687</td>
#     <td class="tg-0lax">0.705</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax"></td>
#     <td class="tg-0lax">1.0</td>
#     <td class="tg-0lax">12</td>
#     <td class="tg-0lax">0.5</td>
#     <td class="tg-0lax">0.5</td>
#     <td class="tg-0lax">0.818</td>
#     <td class="tg-0lax">0.712</td>
#     <td class="tg-0lax">0.684</td>
#     <td class="tg-0lax">0.708</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax"></td>
#     <td class="tg-0lax">1.0</td>
#     <td class="tg-0lax">12</td>
#     <td class="tg-0lax">1.0</td>
#     <td class="tg-0lax">0.0</td>
#     <td class="tg-0lax">0.802</td>
#     <td class="tg-0lax">0.712</td>
#     <td class="tg-0lax">0.681</td>
#     <td class="tg-0lax">0.713</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax"></td>
#     <td class="tg-0lax">1.0</td>
#     <td class="tg-0lax">18</td>
#     <td class="tg-0lax">0.0</td>
#     <td class="tg-0lax">1.0</td>
#     <td class="tg-0lax">0.825</td>
#     <td class="tg-0lax">0.711</td>
#     <td class="tg-0lax">0.687</td>
#     <td class="tg-0lax">0.705</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax"></td>
#     <td class="tg-0lax">1.0</td>
#     <td class="tg-0lax">18</td>
#     <td class="tg-0lax">0.5</td>
#     <td class="tg-0lax">0.5</td>
#     <td class="tg-0lax">0.817</td>
#     <td class="tg-0lax">0.712</td>
#     <td class="tg-0lax">0.684</td>
#     <td class="tg-0lax">0.708</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax"></td>
#     <td class="tg-0lax">1.0</td>
#     <td class="tg-0lax">18</td>
#     <td class="tg-0lax">1.0</td>
#     <td class="tg-0lax">0.0</td>
#     <td class="tg-0lax">0.800</td>
#     <td class="tg-0lax">0.712</td>
#     <td class="tg-0lax">0.681</td>
#     <td class="tg-0lax">0.713</td>
#   </tr>
# </tbody>
# </table>
